# %% [markdown]
# ## Understanding the Geometry of MAD with Interative Plot Widget

# %%
import numpy as np
from math import pi
from test_functions1D import MultiMinimaFunc_numpy, Sinc_numpy, Sin_numpy, MultiMinimaAbsFunc_numpy, DiscontinuousFunc_numpy
import matplotlib.pyplot as plt
from ipywidgets import FloatSlider, Button, Output, VBox, HTML, HBox, Dropdown
from scipy.optimize import differential_evolution

# Initialize global variables for function and plotting range
selected_function = MultiMinimaFunc_numpy  # Set default function to avoid NoneType error
intervalx_a, intervalx_b = -30.0, 30.0
min_T, max_T = 0.1, 100
global_min_x, gobal_min_f = -1.51035, -4.76275
value_T = (min_T + max_T)/2
gamma = 1.89777  # Default gamma for MultiMinima

# Create x_k slider with initial range
x_k_slider = FloatSlider(value=(intervalx_a+intervalx_b)/2, min=intervalx_a, max=intervalx_b, step=0.01, description='x_k:')
fixed_T_slider = FloatSlider(value=value_T, min=min_T, max=max_T, step=0.1, description='Fixed time, T:')

# Create output widget to display the plot
plot_output = Output()

# Create an HTML widget to display the t_threshold value
t_threshold_display = HTML()

# Update the t_threshold display based on current values
def update_t_threshold_display(change=None):
    global t_threshold_display
    """Update the display for the t_threshold and compute its value."""
    # Calculate t_threshold
    if gamma is not None:
        t_threshold = f'{(np.linalg.norm(global_min_x - x_k_slider.value)**2) / (2 * gamma):.2f}'
    else:
        t_threshold = 'UnDefined'
        
    # Create the HTML string with CSS styling
    html_content = f"""
    <div style="font-family: Times New Roman, serif; font-size: 14px;">
        <p><strong>t<sub>threshold</sub> = {t_threshold}, where:</strong></p>
        <p style="margin-left: 20px;">
            T ≥ ||x* - x<sub>k</sub>||<sup>2</sup> / (2γ) = t<sub>threshold</sub> > 0
        </p>
    </div>
    """
    
    # Update the display
    t_threshold_display.value = html_content

# Update the function and range based on dropdown selection
def update_function(change):
    global selected_function, gamma, intervalx_a, intervalx_b

    if change['new'] == 'Sinc':
        min_T, max_T = 1, 1000
        selected_function = Sinc_numpy
        intervalx_a, intervalx_b = -20, 20
        gamma = 0.1259
    
    elif change['new'] == 'Sin':
        min_T, max_T = 1, 500
        selected_function = Sin_numpy
        intervalx_a, intervalx_b = -3.5 * pi, 2.5 * pi
        gamma = None
        # Calculate global minima positions within the specified range
    
    elif change['new'] == 'MultiMinimaAbsFunc':
        min_T, max_T = 0.1, 100
        selected_function = MultiMinimaAbsFunc_numpy
        intervalx_a, intervalx_b = -15, 15
        gamma = 1.43457
        # Calculate global minima positions within the specified range

    elif change['new'] == 'DiscontinuousFunc':
        min_T, max_T = 0.1, 100
        selected_function = DiscontinuousFunc_numpy
        intervalx_a, intervalx_b = -20, 15
        gamma = 7
        # Calculate global minima positions within the specified range

    
    else:  # 'MultiMinima'
        min_T, max_T = 0.1, 100
        selected_function = MultiMinimaFunc_numpy
        intervalx_a, intervalx_b = -30, 30
        gamma = 1.89777
    
    # Update x_k slider range
    x_k_slider.min = intervalx_a
    x_k_slider.max = intervalx_b
    x_k_slider.value = (intervalx_a + intervalx_b) / 2  # Reset slider to the middle
    fixed_T_slider.min = min_T
    fixed_T_slider.max = max_T
    fixed_T_slider.value = (min_T + max_T) / 2 
    
    # Update plot when function changes
    update_t_threshold_display()
    with plot_output:
        plot_output.clear_output() 
        update_plot(None)

# Define the function h(x)
def h(x, fixed_T, x_k):
    return selected_function(x) + (1 / (2 * fixed_T)) * (x - x_k)**2

# Define the function u(x)
def u(x, x_hat, fixed_T):
    return selected_function(x_hat) + (1 / (2 * fixed_T)) * (x_hat - x)**2

# Function to update the plot based on slider values
def update_plot(button):
    global global_min_x, gobal_min_f
    with plot_output:
        fixed_T = fixed_T_slider.value
        x_k = x_k_slider.value
        alpha = alpha_slider.value

        x_values = np.linspace(intervalx_a, intervalx_b, 400)

        # Compute the Moreau Envelope
        u_values = []
        for x in x_values:
            result = differential_evolution(h, [(intervalx_a, intervalx_b)], args=(fixed_T, x))
            u_values.append(result.fun)
        
        # Compute the prox at x_k
        result = differential_evolution(h, [(intervalx_a, intervalx_b)], args=(fixed_T, x_k))
        x_hat = result.x[0]
        f_hat = result.fun

        # Compute the Global Minima
        result = differential_evolution(selected_function, [(intervalx_a, intervalx_b)])
        global_min_x = result.x
        gobal_min_f = result.fun

        # Compute f and the function prox needs to minimize at x_k
        f_values = selected_function(x_values)
        h_values = h(x_values, fixed_T, x_k)

        # Compute x_{k+1} and f(x_{k+1}) using the fact grad(u(xk)) = (xk-prox(xk))/t
        x_k_plus_1 = x_k - alpha * (x_k - x_hat)
        f_x_k_plus_1 = selected_function(x_k_plus_1)

        # Plotting f(x)
        plt.figure(figsize=(12, 8))
        plt.plot(x_values, f_values, label=r'$f(x)$', color='blue')
        plt.plot(x_values, h_values, label=r'Prox function to minimize at $x_k$, $f(x) + \frac{1}{2T} (x - x_k)^2$', color='orange')

        # Plot Moreau Envelope u(x)
        plt.plot(x_values, u_values, label=r'Moreau Envelope, $u(x,T)$', color='green')
        plt.scatter(x_k, f_hat, label=r'Moreau Envelope at $x_k$, $u(x_k,T)$', color='red', marker='x')

        # Mark the Prox at x_k
        plt.scatter(x_hat, f_hat, color='red', zorder=5, label=r'Proximal at x_k, $\hat{x}_k=prox_{Tf}(x_k)$')

        # Calculate the value of f at x_k
        f_xk_value = selected_function(x_k)
        plt.scatter(x_k, f_xk_value, color='black', zorder=5, label=r'Current Iteration $f(x_k)$', marker='x')

        # Mark the global minimum of f(x)
        plt.scatter(global_min_x, gobal_min_f, color='cyan', zorder=5, label=r'Global Minima, $f(x_{true})$', marker='o')

        # Plot the point for f(x_{k+1})
        plt.scatter(x_k_plus_1, f_x_k_plus_1, color='magenta', zorder=5, 
                    label=r'Next Iteration $f(x_{k+1})$, for $x_{k+1}=x_k+\alpha\nabla u(x_k)$', marker='^')

        plt.plot([x_hat, x_k], [f_hat, f_hat], color='red', linewidth=0.8, linestyle=':',label='Line between ' + r' $x_k$ '+f',\n'+r'$prox(x_k)$ and envelope $u(x_k,T)$')
        plt.plot([x_k, x_k], [f_xk_value, f_hat], color='red', linewidth=0.8, linestyle=':')
             
        # Add titles and labels
        plt.title(f'Plot To Visualize Moreau Adaptive Descent, T={fixed_T:.2f}')
        plt.xlabel('x')
        plt.ylabel('y')
        plt.axhline(0, color='black', linewidth=0.5, ls='--')
        plt.axvline(0, color='black', linewidth=0.5, ls='--')

        # Set limits and grid
        plt.xlim(intervalx_a, intervalx_b)

        # Dynamically set the y-limits based on function outputs
        y_min = np.min(f_values)
        y_max = np.max(f_values)

        if y_max < 0:
            # If all values are negative, set the limits to give some visual space
            plt.ylim(1.2 * y_min, 0)  # Set lower limit 20% below min, upper limit at 0
        elif y_min > 0:
            plt.ylim(0.8 * y_min, 1.2 * y_max)  # 20% less than the min if min is positive
        else:
            plt.ylim(1.2 * y_min, 1.2 * y_max)  # 20% more than the min if min is zero or negative

        plt.grid(which='major', linestyle='-', linewidth='0.5')
        plt.minorticks_on()
        plt.gca().xaxis.set_minor_locator(plt.MultipleLocator(1))
        plt.grid(which='minor', linestyle=':', linewidth='0.5')
        plt.legend(loc='best')
        plot_output.clear_output()  # Clear previous output before updating
        # Display the plot
        plt.show()

# Function to update x_k to x_k_plus_1 when button is clicked
def update_x_k(button):
    fixed_T = fixed_T_slider.value
    x_k = x_k_slider.value
    alpha = alpha_slider.value

    # Find the global minimum using the differential_evolution method
    result = differential_evolution(h, [(intervalx_a, intervalx_b)], args=(fixed_T, x_k))

    if result.success:
        x_hat = result.x[0]
        x_k_plus_1 = x_k - alpha * (x_k - x_hat)
        
        # Update the x_k slider value to the new x_k_plus_1
        x_k_slider.value = x_k_plus_1

        # Replot using the updated x_k
        update_plot(button)

# Create buttons and dropdown
iterate_button = Button(description='Iterate and Plot', button_style='info')
iterate_button.on_click(update_x_k)

plot_button = Button(description='Plot', button_style='success')  # New plot button
plot_button.on_click(update_plot)  # Assign update_plot function to this button

alpha_slider = FloatSlider(value=0.5, min=0.05, max=1.9, step=0.05, description='Alpha:')
function_dropdown = Dropdown(options=['MultiMinima', 'Sinc', 'Sin','MultiMinimaAbsFunc','DiscontinuousFunc'], value='MultiMinima', description='Function:')
function_dropdown.observe(update_function, names='value')
x_k_slider.observe(update_t_threshold_display, names='value')

note = HTML("""<p>Select a function from the dropdown and adjust the sliders to modify the values of fixed time <strong>T</strong>, <strong>x_k</strong>, and Step Size <strong>&alpha;</strong>.</p>""")

# Display the interactive widgets and plot
display(VBox([
    HTML('<h2>HJ Moreau Adaptive Descent Visualizer</h2>'),
    note,
    function_dropdown,
    HBox([x_k_slider, fixed_T_slider, alpha_slider]),
    t_threshold_display,  # Display for t_threshold
    HBox([iterate_button, plot_button]),  # Added plot button to the layout
    plot_output
]))

# Initial plot and t_threshold update
update_t_threshold_display()
update_plot(None)
