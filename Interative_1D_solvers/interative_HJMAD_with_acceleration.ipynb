# %%
from Interative_1D_solvers.hj_mad_1d_UI import HJ_MAD_1D_UI

# %%
UI= HJ_MAD_1D_UI()
# Out:
# ...
# -------------------------- RUNNING HJ-MAD ---------------------------
# For the parameters:
# HTML(value="<h3>Slider Values and Function Name</h3><table style='border-collapse: collapse; width: 50%; font-…
# -------------------------- HJ-MAD RESULTS ---------------------------
# HJ-MAD failed to converge with rel grad norm 5.73e-01
# iter =  49 , number of function evaluations =  10000
# Used fixed time =  False
# -------------------------- RUNNING HJ-MAD ---------------------------
# For the parameters:
# HTML(value="<h3>Slider Values and Function Name</h3><table style='border-collapse: collapse; width: 50%; font-…
# -------------------------- HJ-MAD RESULTS ---------------------------
# HJ-MAD converged with rel grad norm 3.66e-01
# iter =  48 , number of function evaluations =  9800
# -------------------------- HJ-MAD RESULTS ---------------------------
# HJ-MAD failed to converge with rel grad norm 8.09e-01
# iter =  49 , number of function evaluations =  10000
# ...
