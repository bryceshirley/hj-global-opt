# %% [markdown]
# # This notebook is based on the paper: "Global-Convergence-Nonconvex-Optimization".
#
# The aim of this project is to find the global solution to
# \begin{equation}
#   \min_{x \in \mathbb{R}^n} f(x).
# \end{equation}
#
# To obtain a global minimizer, the main idea is to minimize the Moreau Envelop instead, which "convexifies" the original function. To make the Moreau envelope tractable, we use connections to Hamilton-Jacobi Equations via the Cole-Hopf and Hopf-Lax formulas to efficiently compute the gradients of the Moreau envelope.

# %%
import os
import sys
import matplotlib.pyplot as plt
import numpy as np
import torch
import math
import time
import random
from typing import Optional 

epsilon_double = np.finfo(np.float64).eps

from test_functions import Griewank, AlpineN1, Drop_Wave, Levy, Rastrigin, Ackley
from test_functions import Griewank_numpy, AlpineN1_numpy, Drop_Wave_numpy, Levy_numpy, Rastrigin_numpy, Ackley_numpy

from test_functions import MultiMinimaFunc, MultiMinimaAbsFunc
from test_functions import MultiMinimaFunc_numpy, MultiMinimaAbsFunc_numpy

seed   = 30
torch.manual_seed(seed)

# %% [markdown]
# ### Create Class for Hamilton-Jacobi Moreau Adaptive Descent (HJ_MAD)
#
# The Moreau envelop of $f$ is given by
# \begin{equation}
#   u(x,t) \triangleq \inf_{z\in \mathbb{R}^n} f(z) + \dfrac{1}{2t}\|z-x\|^2.
# \end{equation}
#
# We leverage the fact that the solution to the Moreau envelope above satisfies the Hamilton-Jacobi Equation
# \begin{equation}
#   \begin{split}
#     u_t^\delta  + \frac{1}{2}\|Du^\delta  \|^2 \ = \frac{\delta}{2} \Delta u^\delta \qquad &\text{ in }  \mathbb{R}^n\times (0,T]
#     \\
#     u = f \qquad &\text{ in } \mathbb{R}^n\times \{t = 0\}
#   \end{split}
# \end{equation}
# when $\delta = 0$.
#
# By adding a viscous term ($\delta > 0$), we are able to approximate the solution to the HJ equation using the Cole-Hopf formula to obtain
# \begin{equation}
#   u^\delta(x,t) = - \delta \ln\Big(\Phi_t * \exp(-f/\delta)\Big)(x) = - \delta \ln \int_{\mathbb{R}^n} \Phi(x-y,t)  \exp\left(\frac{-f(y)}{\delta}\right) dy
# \end{equation}
# where
# \begin{equation}
#   \Phi(x,t) = \frac{1}{{(4\pi \delta t)}^{n/2}} \exp{\frac{-\|x\|^2}{4\delta t}}.
# \end{equation}
# This allows us to write the Moreau Envelope (and its gradient) explicitly as an expectation. In this case, we compute the gradient as
# \begin{equation}
#   \nabla u^\delta(x,t) = \dfrac{1}{t}\cdot  \dfrac{\mathbb{E}_{y\sim  \mathbb{P}_{x,t}}\left[(x-y) \exp\left(-\delta^{-1}\tilde{f}(y)\right) \right]}
#     {\mathbb{E}_{y\sim  \mathbb{P}_{x,t}}\left[ \exp\left(-\delta^{-1} \tilde{f}(y)\right) \right]}
# \end{equation}

# %% [markdown]
# ### Define classes for HJ-MD-LS

# %%
from hj_md_ls import HJ_MAD_LS, AdaptiveDeltaConfig, AdaptiveTimeConfig, PlotConfig

# %% [markdown]
# ### Set up hyperparameters for HJ-MAD for different functions

# %%
# # Default values
delta         = 5e-2
max_iters     = int(1e4) #int(1e5)
tol           = 5e-2#7e-4


# Set the number of trials to run
avg_trials = 1
sat_tol = 1e-8

# # # def f(x):
# # #   return MultiMinimaFunc(x)
# # # def f_numpy(x):
# # #   return MultiMinimaFunc_numpy(x)
# # # ax_bry  = 30
# # # f_name  = 'MultiMinimaFunc'
# # # dim = 1; int_samples = int(100);
# # # x0      = -30*torch.ones(dim, dtype=torch.double)
# # # x_true  = -1.51034569*torch.ones(dim, dtype=torch.double)

# # # delta         = 0.1
# # # max_iters     = int(100)
# # # tol           = 1e-3
# # # momentum = 0.5

# # # theta         = 1.0 # note: larger theta => easier to increase time
# # # beta          = 0.0
# # # t_min     = 1e-1
# # # t_max     = 300
# # # t_init    = 220
# # # alpha     = 0.1
# # # eta_min = 0.99
# # # eta_plus = 5.0
# # # eta_vec = [eta_min, eta_plus]


# # # # ----------------------------------------------------------------------------------------------------

# def f(x):
#   return Griewank(x)
# def f_numpy(x):
#   return Griewank_numpy(x)
# ax_bry  = 20
# f_name  = 'Griewank'
# dim = 2; int_samples = int(5);
# int_samples_line = int(10000)
# x0      = 10*torch.ones(dim, dtype=torch.double)
# x_true  = torch.zeros(dim, dtype=torch.double)


# max_iters     = int(1e5)

# delta         = 1e-3#1e-6 #1e-6

# tol           = 5e-3

# t    = 1e4



# # # ---------------------------------------------------------------------------------------------------- To Test:

# avg_trials = 1
# max_iters     = int(1e5)

# def f(x):
#   return Griewank(x)
# def f_numpy(x):
#   return Griewank_numpy(x)
# ax_bry  = 20
# f_name  = 'Griewank'
# dim = 500; int_samples = int(2)
# int_samples_line = int(1e2)
# x0      = 10*torch.ones(dim, dtype=torch.double)
# x_true  = torch.zeros(dim, dtype=torch.double)
# rescale0      = 2**(-13)
# delta         = 1e-6 #1e-6

# tol           = 5e-3

# t    = 1e-2/delta

# # # ----------------------------------------------------------------------------------------------------

# def f(x):
#   return Drop_Wave(x)
# def f_numpy(x):
#   return Drop_Wave_numpy(x)
# ax_bry  = 20

# f_name  = 'Drop_Wave'
# rescale0      = 1
# dim = 2; int_samples = int(100)

# x0      = 10*torch.ones(dim, dtype=torch.double)
# x_true  = torch.zeros(dim, dtype=torch.double)

# delta         = 1e-6

# t = int(2e1)/1e-4#delta


# # # # ----------------------------------------------------------------------------------------------------

# def f(x):
#   return AlpineN1(x)
# def f_numpy(x):
#   return AlpineN1_numpy(x)
# ax_bry  = 20
# f_name  = 'AlpineN1'

# dim = 2; int_samples = int(5)

# x0      = 10*torch.ones(dim, dtype=torch.double)
# x_true  = torch.zeros(dim, dtype=torch.double)
# delta         = 5e-6


# t = int(2e1)/5e-4

# # # ----------------------------------------------------------------------------------------------------
# avg_trials = 1
# def f(x):
#   return Levy(x)
# def f_numpy(x):
#   return Levy_numpy(x)

# ax_bry  = 20
# f_name  = 'Levy'

# # Set the number of trials to run
# rescale0 = 1
# tol           = 5e-3
# sat_tol = 1e-5
# max_iters     = int(5e2)
# delta         = 1e-4


# dim = 2; 
# int_samples = int(10)
# int_samples_line = int(10000)
# x0      = -15*torch.ones(dim, dtype=torch.double)
# # x0[1] = 0
# x_true  = torch.ones(dim, dtype=torch.double)

# t     = 1e4 # int(2e2)/delta

# avg_trials = 1
# def f(x):
#   return Levy(x)
# def f_numpy(x):
#   return Levy_numpy(x)

# ax_bry  = 20
# f_name  = 'Levy'

# # Set the number of trials to run
# rescale0 = 1
# tol           = 5e-3
# sat_tol = 1e-5
# max_iters     = int(5e2)
# delta         = 1e-4


# dim = 2; 
# int_samples = int(1000)
# int_samples_line = int(10000)
# x0      = -15*torch.ones(dim, dtype=torch.double)
# # x0[1] = 0
# x_true  = torch.ones(dim, dtype=torch.double)

# t     = 1e4 # int(2e2)/delta

# # # ----------------------------------------------------------------------------------------------------

# avg_trials = 1
# def f(x):
#   return Levy(x)
# def f_numpy(x):
#   return Levy_numpy(x)

# ax_bry  = 20
# f_name  = 'Levy'

# # Set the number of trials to run
# rescale0 = 1
# tol           = 5e-3
# sat_tol = 1e-5
# max_iters     = int(5e2)
# delta         = 1e-5


# dim = 2; 
# int_samples = int(100)
# int_samples_line = int(10000)
# x0      = -15*torch.ones(dim, dtype=torch.double)
# x0[1] = 0
# x_true  = torch.ones(dim, dtype=torch.double)

# t     = 1e4 # int(2e2)/delta



# # # ----------------------------------------------------------------------------------------------------


avg_trials = 1
def f(x):
  return Levy(x)
def f_numpy(x):
  return Levy_numpy(x)

ax_bry  = 20
f_name  = 'Levy'

# Set the number of trials to run
dim = 200; 
x0      = -15*torch.ones(dim, dtype=torch.double)
x_true  = torch.ones(dim, dtype=torch.double)
tol           = 5e-2

int_samples = int(1e3)

delta0 = 1e-3
t0 = 500
stepsize = 0.2

# Cauchy
hj_md_cauchy= HJ_MAD_LS(
    f=f,
    x_true=x_true,
    delta=delta0,
    t=t0,
    int_samples=int_samples,
    max_iters=max_iters,
    tol=tol,
    verbose=True,
    distribution="Cauchy",
    line_search=False,
    step_size=stepsize,
    adaptive_delta_config=AdaptiveDeltaConfig(),
    adaptive_time_config=AdaptiveTimeConfig(t_max=1e5)  # Example values
)

# Gaussian
hj_md_gauss = HJ_MAD_LS(
    f=f,
    x_true=x_true,
    delta=0.1,
    t=t0,
    int_samples=int_samples,
    max_iters=max_iters,
    tol=tol,
    verbose=True,
    distribution="Gaussian",
    line_search=False,
    step_size=stepsize,
    adaptive_delta_config=AdaptiveDeltaConfig(),
    adaptive_time_config=AdaptiveTimeConfig(t_max=1e10),
)

# # # ----------------------------------------------------------------------------------------------------

# avg_trials = 1
# def f(x):
#   return Levy(x)
# def f_numpy(x):
#   return Levy_numpy(x)

# ax_bry  = 20
# f_name  = 'Levy'

# # Set the number of trials to run
# dim = 500; 
# x0      = -15*torch.ones(dim, dtype=torch.double)
# x_true  = torch.ones(dim, dtype=torch.double)
# tol           = 5e-4
# sat_tol = 1e-5
# max_iters     = int(1e3)

# # Important parameters
# delta         = 1e-3 # Smaller delta => more samples required but fewer iterations
# t     = 100#int(2e2)/delta

# int_samples = int(100)
# int_samples_line = int(500)


# # # ----------------------------------------------------------------------------------------------------

# def f(x):
#   return Rastrigin(x)
# def f_numpy(x):
#   return Rastrigin_numpy(x)
# ax_bry  = 20
# f_name  = 'Rastrigin'

# delta         = 5e-5
# dim = 2; int_samples = int(9);
# x0      = 10*torch.ones(dim, dtype=torch.double)
# x_true  = torch.zeros(dim, dtype=torch.double)

# t = int(2e1)/5e-2



# # # # ----------------------------------------------------------------------------------------------------

# def f(x):
#   return Ackley(x)
# def f_numpy(x):
#   return Ackley_numpy(x)
# ax_bry  = 20
# f_name  = 'Ackley'

# dim = 2; int_samples = int(3);
# int_samples_line = int(100)
# x0      = 10*torch.ones(dim, dtype=torch.double)
# x_true  = torch.zeros(dim, dtype=torch.double)

# t = int(2e1)/delta

# %% [markdown]
# ## Line Search Version

# %%
# Initialize accumulators for averages
avg_func_evals = 0
sum_elapsed_time = 0
total_iterations = 0  # To store total iterations across trials
avg_completion_error = 0  # To store completion error across trials
avg_rescale_factor_reached = 0  # To store rescale factor reached across trials
convergened_count = 0
avg_successful_ls = 0
# Run the specified number of trials
for _ in range(avg_trials):
    start_time = time.time()  # Record the start time

    # Execute the HJ_MAD_CD algorithm and retrieve results
    x_opt_cauchy, xk_hist_cauchy, xk_error_hist_cauchy, fk_hist_cauchy,delta_hist_cauchy,tk_hist_cauchy, successful_ls_portion = hj_md_cauchy.run(x0)

    elapsed_time = time.time() - start_time  # Calculate elapsed time
    sum_elapsed_time += elapsed_time  # Accumulate elapsed time

    total_iterations += len(xk_error_hist_cauchy)-1  # Add iterations used in this trial
    avg_func_evals += len(xk_error_hist_cauchy) *int_samples  # Update average function evaluations
    avg_completion_error += torch.norm(x_opt_cauchy -x_true) # Ensure the final error is the true error 
    avg_successful_ls += successful_ls_portion

    if torch.norm(x_opt_cauchy -x_true) <= tol:
        convergened_count += 1


    #print(f"Elapsed time: {elapsed_time:.4f} seconds")  # Print elapsed time for the current trial

# Compute averages after all trials
avg_func_evals /= avg_trials  # Average function evaluations per trial
average_iterations = total_iterations / avg_trials  # Average number of iterations per trial
avg_completion_error /= avg_trials  # Average completion error across all trials
avg_rescale_factor_reached /= avg_trials  # Average rescale factor reached across all trials
portion_converged = convergened_count / avg_trials
avg_successful_ls /= avg_trials
# Output results
print(f"\n\nSummary of Results for {avg_trials} Trials HJ-MD-LS:")
print("=" * 40)
print(f"{'Average Function Evaluations:':<35} {avg_func_evals}")
print(f"{'Average Completion Error:':<35} {avg_completion_error:.2e} (Tolerance: {tol:.2e})")
print(f"{'Portion Converged:':<35} {portion_converged:.2%}")
print(f"{'Average Successful Linesearch:':<35} {avg_successful_ls:.2%}")
print(f"{'Average Iterations to Convergence/Stopping:':<35} {average_iterations:.2f}")
print(f"{'Average Elapsed Time:':<35} {sum_elapsed_time / avg_trials:.4f} seconds")
# Out:
# -------------------------- RUNNING HJ-MAD-LS Algorithm ---------------------------
# dimension =  200 n_samples =  1000
# [  0]: fk = 2.26e+02 | error = 2.57e+04 | deltak = 1.00e-03 | tk = 5.00e+02
# [  1]: fk = 2.37e+04 | error = 2.24e+02 | deltak = 1.00e-03 | tk = 5.00e+02
# [  2]: fk = 2.25e+04 | error = 2.24e+02 | deltak = 1.00e-03 | tk = 4.95e+02
# [  3]: fk = 2.08e+04 | error = 2.23e+02 | deltak = 1.00e-03 | tk = 5.00e+02
# [  4]: fk = 1.98e+04 | error = 2.22e+02 | deltak = 1.00e-03 | tk = 5.05e+02
# [  5]: fk = 1.95e+04 | error = 2.22e+02 | deltak = 1.00e-03 | tk = 5.00e+02
# [  6]: fk = 1.91e+04 | error = 2.21e+02 | deltak = 1.00e-03 | tk = 5.05e+02
# [  7]: fk = 1.78e+04 | error = 2.21e+02 | deltak = 1.00e-03 | tk = 5.00e+02
# [  8]: fk = 1.82e+04 | error = 2.21e+02 | deltak = 1.00e-03 | tk = 4.95e+02
# [  9]: fk = 1.77e+04 | error = 2.20e+02 | deltak = 1.00e-03 | tk = 5.00e+02
# [ 10]: fk = 1.69e+04 | error = 2.19e+02 | deltak = 1.00e-03 | tk = 5.05e+02
# [ 11]: fk = 1.70e+04 | error = 2.19e+02 | deltak = 1.00e-03 | tk = 5.00e+02
# [ 12]: fk = 1.66e+04 | error = 2.18e+02 | deltak = 1.00e-03 | tk = 4.95e+02
# [ 13]: fk = 1.73e+04 | error = 2.18e+02 | deltak = 1.00e-03 | tk = 5.00e+02
# [ 14]: fk = 1.71e+04 | error = 2.18e+02 | deltak = 1.00e-03 | tk = 5.05e+02
# [ 15]: fk = 1.65e+04 | error = 2.18e+02 | deltak = 1.00e-03 | tk = 5.00e+02
# [ 16]: fk = 1.63e+04 | error = 2.18e+02 | deltak = 1.00e-03 | tk = 4.95e+02
# [ 17]: fk = 1.63e+04 | error = 2.18e+02 | deltak = 1.00e-03 | tk = 5.00e+02
# [ 18]: fk = 1.63e+04 | error = 2.17e+02 | deltak = 1.00e-03 | tk = 4.95e+02
# [ 19]: fk = 1.61e+04 | error = 2.16e+02 | deltak = 1.00e-03 | tk = 5.00e+02
# [ 20]: fk = 1.60e+04 | error = 2.14e+02 | deltak = 1.00e-03 | tk = 5.05e+02
# [ 21]: fk = 1.60e+04 | error = 2.14e+02 | deltak = 1.00e-03 | tk = 5.00e+02
# [ 22]: fk = 1.54e+04 | error = 2.14e+02 | deltak = 1.00e-03 | tk = 4.95e+02
# [ 23]: fk = 1.63e+04 | error = 2.12e+02 | deltak = 1.00e-03 | tk = 4.99e+02
# [ 24]: fk = 1.60e+04 | error = 2.11e+02 | deltak = 1.00e-03 | tk = 4.94e+02
# [ 25]: fk = 1.55e+04 | error = 2.11e+02 | deltak = 1.00e-03 | tk = 4.99e+02
# [ 26]: fk = 1.57e+04 | error = 2.10e+02 | deltak = 1.00e-03 | tk = 4.94e+02
# [ 27]: fk = 1.58e+04 | error = 2.08e+02 | deltak = 1.00e-03 | tk = 4.99e+02
# [ 28]: fk = 1.54e+04 | error = 2.07e+02 | deltak = 1.00e-03 | tk = 5.04e+02
# [ 29]: fk = 1.45e+04 | error = 2.07e+02 | deltak = 1.00e-03 | tk = 4.99e+02
# [ 30]: fk = 1.43e+04 | error = 2.05e+02 | deltak = 1.00e-03 | tk = 5.04e+02
# [ 31]: fk = 1.54e+04 | error = 2.05e+02 | deltak = 1.00e-03 | tk = 5.09e+02
# [ 32]: fk = 1.50e+04 | error = 2.05e+02 | deltak = 1.00e-03 | tk = 5.14e+02
# [ 33]: fk = 1.47e+04 | error = 2.04e+02 | deltak = 1.00e-03 | tk = 5.20e+02
# [ 34]: fk = 1.46e+04 | error = 2.03e+02 | deltak = 1.00e-03 | tk = 5.25e+02
# [ 35]: fk = 1.44e+04 | error = 2.03e+02 | deltak = 1.00e-03 | tk = 5.20e+02
# [ 36]: fk = 1.45e+04 | error = 2.00e+02 | deltak = 1.00e-03 | tk = 5.25e+02
# [ 37]: fk = 1.46e+04 | error = 2.00e+02 | deltak = 1.00e-03 | tk = 5.19e+02
# [ 38]: fk = 1.40e+04 | error = 1.99e+02 | deltak = 1.00e-03 | tk = 5.25e+02
# [ 39]: fk = 1.37e+04 | error = 1.98e+02 | deltak = 1.00e-03 | tk = 5.19e+02
# [ 40]: fk = 1.30e+04 | error = 1.98e+02 | deltak = 1.00e-03 | tk = 5.14e+02
#     f(xk): 1.29640e+04 | f(prox): 1.31631e+04
# [ 41]: fk = 1.29e+04 | error = 1.96e+02 | deltak = 9.90e-04 | tk = 5.19e+02
# [ 42]: fk = 1.30e+04 | error = 1.96e+02 | deltak = 9.90e-04 | tk = 5.14e+02
# [ 43]: fk = 1.22e+04 | error = 1.95e+02 | deltak = 9.90e-04 | tk = 5.19e+02
# [ 44]: fk = 1.26e+04 | error = 1.93e+02 | deltak = 9.90e-04 | tk = 5.14e+02
# [ 45]: fk = 1.32e+04 | error = 1.91e+02 | deltak = 9.90e-04 | tk = 5.09e+02
# [ 46]: fk = 1.28e+04 | error = 1.91e+02 | deltak = 9.90e-04 | tk = 5.04e+02
# [ 47]: fk = 1.31e+04 | error = 1.90e+02 | deltak = 9.90e-04 | tk = 5.09e+02
# [ 48]: fk = 1.23e+04 | error = 1.91e+02 | deltak = 9.90e-04 | tk = 5.04e+02
# [ 49]: fk = 1.20e+04 | error = 1.91e+02 | deltak = 9.90e-04 | tk = 4.99e+02
# [ 50]: fk = 1.29e+04 | error = 1.90e+02 | deltak = 9.90e-04 | tk = 5.04e+02
# [ 51]: fk = 1.29e+04 | error = 1.89e+02 | deltak = 9.90e-04 | tk = 4.99e+02
# [ 52]: fk = 1.29e+04 | error = 1.89e+02 | deltak = 9.90e-04 | tk = 5.04e+02
# [ 53]: fk = 1.21e+04 | error = 1.88e+02 | deltak = 9.90e-04 | tk = 5.09e+02
# [ 54]: fk = 1.21e+04 | error = 1.88e+02 | deltak = 9.90e-04 | tk = 5.04e+02
# [ 55]: fk = 1.21e+04 | error = 1.88e+02 | deltak = 9.90e-04 | tk = 5.09e+02
# [ 56]: fk = 1.23e+04 | error = 1.88e+02 | deltak = 9.90e-04 | tk = 5.14e+02
# [ 57]: fk = 1.23e+04 | error = 1.86e+02 | deltak = 9.90e-04 | tk = 5.19e+02
# [ 58]: fk = 1.16e+04 | error = 1.85e+02 | deltak = 9.90e-04 | tk = 5.14e+02
# [ 59]: fk = 1.16e+04 | error = 1.85e+02 | deltak = 9.90e-04 | tk = 5.09e+02
# [ 60]: fk = 1.11e+04 | error = 1.83e+02 | deltak = 9.90e-04 | tk = 5.14e+02
#     f(xk): 1.11107e+04 | f(prox): 1.12698e+04
# [ 61]: fk = 1.20e+04 | error = 1.83e+02 | deltak = 9.80e-04 | tk = 5.19e+02
# [ 62]: fk = 1.16e+04 | error = 1.81e+02 | deltak = 9.80e-04 | tk = 5.24e+02
#     f(xk): 1.15532e+04 | f(prox): 1.16704e+04
# [ 63]: fk = 1.14e+04 | error = 1.80e+02 | deltak = 9.70e-04 | tk = 5.29e+02
# [ 64]: fk = 1.13e+04 | error = 1.79e+02 | deltak = 9.70e-04 | tk = 5.24e+02
# [ 65]: fk = 1.12e+04 | error = 1.78e+02 | deltak = 9.70e-04 | tk = 5.29e+02
# [ 66]: fk = 1.14e+04 | error = 1.78e+02 | deltak = 9.70e-04 | tk = 5.35e+02
# [ 67]: fk = 1.12e+04 | error = 1.77e+02 | deltak = 9.70e-04 | tk = 5.40e+02
# [ 68]: fk = 1.10e+04 | error = 1.75e+02 | deltak = 9.70e-04 | tk = 5.45e+02
# [ 69]: fk = 1.10e+04 | error = 1.74e+02 | deltak = 9.70e-04 | tk = 5.40e+02
# [ 70]: fk = 1.09e+04 | error = 1.72e+02 | deltak = 9.70e-04 | tk = 5.45e+02
# [ 71]: fk = 1.05e+04 | error = 1.71e+02 | deltak = 9.70e-04 | tk = 5.51e+02
# [ 72]: fk = 9.95e+03 | error = 1.70e+02 | deltak = 9.70e-04 | tk = 5.45e+02
#     f(xk): 9.94917e+03 | f(prox): 1.00274e+04
# [ 73]: fk = 9.99e+03 | error = 1.68e+02 | deltak = 9.61e-04 | tk = 5.51e+02
# [ 74]: fk = 1.01e+04 | error = 1.67e+02 | deltak = 9.61e-04 | tk = 5.56e+02
# [ 75]: fk = 9.61e+03 | error = 1.66e+02 | deltak = 9.61e-04 | tk = 5.62e+02
#     f(xk): 9.60962e+03 | f(prox): 9.68477e+03
# [ 76]: fk = 9.93e+03 | error = 1.65e+02 | deltak = 9.51e-04 | tk = 5.56e+02
# [ 77]: fk = 1.01e+04 | error = 1.65e+02 | deltak = 9.51e-04 | tk = 5.50e+02
# [ 78]: fk = 1.00e+04 | error = 1.64e+02 | deltak = 9.51e-04 | tk = 5.56e+02
# [ 79]: fk = 9.91e+03 | error = 1.63e+02 | deltak = 9.51e-04 | tk = 5.50e+02
# [ 80]: fk = 1.01e+04 | error = 1.63e+02 | deltak = 9.51e-04 | tk = 5.56e+02
# [ 81]: fk = 9.72e+03 | error = 1.62e+02 | deltak = 9.51e-04 | tk = 5.62e+02
# [ 82]: fk = 9.25e+03 | error = 1.61e+02 | deltak = 9.51e-04 | tk = 5.67e+02
# [ 83]: fk = 9.50e+03 | error = 1.60e+02 | deltak = 9.51e-04 | tk = 5.61e+02
# [ 84]: fk = 9.35e+03 | error = 1.59e+02 | deltak = 9.51e-04 | tk = 5.56e+02
# [ 85]: fk = 9.21e+03 | error = 1.58e+02 | deltak = 9.51e-04 | tk = 5.61e+02
# [ 86]: fk = 9.17e+03 | error = 1.57e+02 | deltak = 9.51e-04 | tk = 5.67e+02
# [ 87]: fk = 8.96e+03 | error = 1.55e+02 | deltak = 9.51e-04 | tk = 5.61e+02
# [ 88]: fk = 8.72e+03 | error = 1.54e+02 | deltak = 9.51e-04 | tk = 5.67e+02
# [ 89]: fk = 8.30e+03 | error = 1.51e+02 | deltak = 9.51e-04 | tk = 5.73e+02
# [ 90]: fk = 8.57e+03 | error = 1.53e+02 | deltak = 9.51e-04 | tk = 5.78e+02
# [ 91]: fk = 8.39e+03 | error = 1.51e+02 | deltak = 9.51e-04 | tk = 5.84e+02
# [ 92]: fk = 8.08e+03 | error = 1.51e+02 | deltak = 9.51e-04 | tk = 5.78e+02
# [ 93]: fk = 8.10e+03 | error = 1.48e+02 | deltak = 9.51e-04 | tk = 5.84e+02
# [ 94]: fk = 7.71e+03 | error = 1.47e+02 | deltak = 9.51e-04 | tk = 5.78e+02
# [ 95]: fk = 7.56e+03 | error = 1.46e+02 | deltak = 9.51e-04 | tk = 5.72e+02
# [ 96]: fk = 7.66e+03 | error = 1.46e+02 | deltak = 9.51e-04 | tk = 5.78e+02
# [ 97]: fk = 7.89e+03 | error = 1.45e+02 | deltak = 9.51e-04 | tk = 5.72e+02
# [ 98]: fk = 7.87e+03 | error = 1.45e+02 | deltak = 9.51e-04 | tk = 5.78e+02
# [ 99]: fk = 7.57e+03 | error = 1.46e+02 | deltak = 9.51e-04 | tk = 5.84e+02
# [100]: fk = 7.24e+03 | error = 1.45e+02 | deltak = 9.51e-04 | tk = 5.90e+02
#     f(xk): 7.23826e+03 | f(prox): 7.25031e+03
# [101]: fk = 7.24e+03 | error = 1.45e+02 | deltak = 9.41e-04 | tk = 5.96e+02
# [102]: fk = 6.80e+03 | error = 1.45e+02 | deltak = 9.41e-04 | tk = 6.02e+02
# [103]: fk = 7.02e+03 | error = 1.45e+02 | deltak = 9.41e-04 | tk = 6.08e+02
#     f(xk): 7.01723e+03 | f(prox): 7.26860e+03
# [104]: fk = 7.21e+03 | error = 1.45e+02 | deltak = 9.32e-04 | tk = 6.02e+02
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 14
#      11 start_time = time.time()  # Record the start time
#      13 # Execute the HJ_MAD_CD algorithm and retrieve results
# ---> 14 x_opt_cauchy, xk_hist_cauchy, xk_error_hist_cauchy, fk_hist_cauchy,delta_hist_cauchy,tk_hist_cauchy, successful_ls_portion = hj_md_cauchy.run(x0)
#      16 elapsed_time = time.time() - start_time  # Calculate elapsed time
#      17 sum_elapsed_time += elapsed_time  # Accumulate elapsed time
#
# File ~/hj-global-opt/hj_md_ls.py:560, in HJ_MAD_LS.run(self, x0)
#     558     prox_xk  = self.compute_directional_prox_gauss_hermite(xk,deltak,tk)
#     559 else:
# --> 560     prox_xk = self.compute_directional_prox(xk,deltak,tk)
#     562 f_prox = self.f(prox_xk.view(1, self.n_features))
#     564 # Update Delta
#
# File ~/hj-global-opt/hj_md_ls.py:457, in HJ_MAD_LS.compute_directional_prox(self, xk, deltak, tk)
#     454     cauchy_dist = torch.distributions.Cauchy(loc=xk, scale=standard_deviation)
#     456     # Sample `self.int_samples` points, result shape: (self.int_samples, n_features)
# --> 457     y = cauchy_dist.sample((self.int_samples,))
#     458 else:
#     459     y = xk_expanded + standard_deviation*torch.randn(self.int_samples, self.n_features)
#
# File ~/miniconda3/envs/myenv38/lib/python3.8/site-packages/torch/distributions/distribution.py:151, in Distribution.sample(self, sample_shape)
#     146 """
#     147 Generates a sample_shape shaped sample or sample_shape shaped batch of
#     148 samples if the distribution parameters are batched.
#     149 """
#     150 with torch.no_grad():
# --> 151     return self.rsample(sample_shape)
#
# File ~/miniconda3/envs/myenv38/lib/python3.8/site-packages/torch/distributions/cauchy.py:62, in Cauchy.rsample(self, sample_shape)
#      60 def rsample(self, sample_shape=torch.Size()):
#      61     shape = self._extended_shape(sample_shape)
# ---> 62     eps = self.loc.new(shape).cauchy_()
#      63     return self.loc + eps * self.scale
#
# KeyboardInterrupt:

# %%
# Initialize accumulators for averages
avg_func_evals = 0
sum_elapsed_time = 0
total_iterations = 0  # To store total iterations across trials
avg_completion_error = 0  # To store completion error across trials
avg_rescale_factor_reached = 0  # To store rescale factor reached across trials
convergened_count = 0
avg_successful_ls = 0
# Run the specified number of trials
for _ in range(avg_trials):
    start_time = time.time()  # Record the start time


    # Execute the HJ_MAD_CD algorithm and retrieve results
    x_opt_gauss, xk_hist_gauss, xk_error_hist_gauss, fk_hist_gauss,delta_hist_gauss,tk_hist_gauss, successful_ls_portion = hj_md_gauss.run(x0)

    elapsed_time = time.time() - start_time  # Calculate elapsed time
    sum_elapsed_time += elapsed_time  # Accumulate elapsed time

    total_iterations += len(xk_error_hist_gauss)-1  # Add iterations used in this trial
    avg_func_evals += len(xk_error_hist_gauss) * (5*3)  # Update average function evaluations
    avg_completion_error += torch.norm(x_opt_gauss -x_true) # Ensure the final error is the true error 
    avg_successful_ls += successful_ls_portion

    if xk_error_hist_cauchy[-1] <= tol:
        convergened_count += 1


    #print(f"Elapsed time: {elapsed_time:.4f} seconds")  # Print elapsed time for the current trial

# Compute averages after all trials
avg_func_evals /= avg_trials  # Average function evaluations per trial
average_iterations = total_iterations / avg_trials  # Average number of iterations per trial
avg_completion_error /= avg_trials  # Average completion error across all trials
avg_rescale_factor_reached /= avg_trials  # Average rescale factor reached across all trials
portion_converged = convergened_count / avg_trials
avg_successful_ls /= avg_trials
# Output results
print(f"\n\nSummary of Results for {avg_trials} Trials HJ-MD-LS:")
print("=" * 40)
print(f"{'Average Function Evaluations:':<35} {avg_func_evals}")
print(f"{'Average Completion Error:':<35} {avg_completion_error:.2e} (Tolerance: {tol:.2e})")
print(f"{'Portion Converged:':<35} {portion_converged:.2%}")
print(f"{'Average Successful Linesearch:':<35} {avg_successful_ls:.2%}")
print(f"{'Average Iterations to Convergence/Stopping:':<35} {average_iterations:.2f}")
print(f"{'Average Elapsed Time:':<35} {sum_elapsed_time / avg_trials:.4f} seconds")
# Out:
# -------------------------- RUNNING HJ-MAD-LS Algorithm ---------------------------
# dimension =  200 n_samples =  1000
# [  0]: fk = 2.26e+02 | error = 2.57e+04 | deltak = 1.00e-01 | tk = 5.00e+02
#     Improvement from line search | f(prox_ls): 1.66487e+04
# [  1]: fk = 1.66e+04 | error = 2.28e+02 | deltak = 1.00e-01 | tk = 5.00e+02
#     f(xk): 1.66487e+04 | f(prox): 1.80462e+04
#     Improvement from line search | f(prox_ls): 1.65174e+04
# [  2]: fk = 1.65e+04 | error = 2.28e+02 | deltak = 9.90e-02 | tk = 4.95e+02
#     f(xk): 1.65174e+04 | f(prox): 1.72363e+04
#     Improvement from line search | f(prox_ls): 1.65129e+04
# [  3]: fk = 1.65e+04 | error = 2.28e+02 | deltak = 9.80e-02 | tk = 4.90e+02
#     f(xk): 1.65129e+04 | f(prox): 1.73011e+04
#     Improvement from line search | f(prox_ls): 1.64993e+04
# [  4]: fk = 1.65e+04 | error = 2.28e+02 | deltak = 9.70e-02 | tk = 4.95e+02
#     f(xk): 1.64993e+04 | f(prox): 1.82807e+04
#     Improvement from line search | f(prox_ls): 1.64249e+04
# [  5]: fk = 1.64e+04 | error = 2.28e+02 | deltak = 9.61e-02 | tk = 5.00e+02
#     f(xk): 1.64249e+04 | f(prox): 1.72580e+04
#     Improvement from line search | f(prox_ls): 1.61786e+04
# [  6]: fk = 1.62e+04 | error = 2.28e+02 | deltak = 9.51e-02 | tk = 5.05e+02
#     f(xk): 1.61786e+04 | f(prox): 1.74118e+04
#     Improvement from line search | f(prox_ls): 1.61787e+04
# [  7]: fk = 1.62e+04 | error = 2.28e+02 | deltak = 9.41e-02 | tk = 5.00e+02
#     f(xk): 1.61787e+04 | f(prox): 1.78116e+04
#     Improvement from line search | f(prox_ls): 1.61742e+04
# [  8]: fk = 1.62e+04 | error = 2.28e+02 | deltak = 9.32e-02 | tk = 5.05e+02
#     f(xk): 1.61742e+04 | f(prox): 1.78510e+04
#     Improvement from line search | f(prox_ls): 1.60924e+04
# [  9]: fk = 1.61e+04 | error = 2.29e+02 | deltak = 9.23e-02 | tk = 5.10e+02
#     f(xk): 1.60924e+04 | f(prox): 1.76423e+04
#     Improvement from line search | f(prox_ls): 1.60669e+04
# [ 10]: fk = 1.61e+04 | error = 2.29e+02 | deltak = 9.14e-02 | tk = 5.05e+02
#     f(xk): 1.60669e+04 | f(prox): 1.70778e+04
#     Improvement from line search | f(prox_ls): 1.59819e+04
# [ 11]: fk = 1.60e+04 | error = 2.29e+02 | deltak = 9.04e-02 | tk = 5.10e+02
#     f(xk): 1.59819e+04 | f(prox): 1.73303e+04
#     Improvement from line search | f(prox_ls): 1.59270e+04
# [ 12]: fk = 1.59e+04 | error = 2.29e+02 | deltak = 8.95e-02 | tk = 5.05e+02
#     f(xk): 1.59270e+04 | f(prox): 1.70149e+04
#     Improvement from line search | f(prox_ls): 1.59279e+04
# [ 13]: fk = 1.59e+04 | error = 2.29e+02 | deltak = 8.86e-02 | tk = 5.00e+02
#     f(xk): 1.59279e+04 | f(prox): 1.75553e+04
#     Improvement from line search | f(prox_ls): 1.58563e+04
# [ 14]: fk = 1.59e+04 | error = 2.29e+02 | deltak = 8.78e-02 | tk = 5.05e+02
#     f(xk): 1.58563e+04 | f(prox): 1.67632e+04
#     Improvement from line search | f(prox_ls): 1.56387e+04
# [ 15]: fk = 1.56e+04 | error = 2.28e+02 | deltak = 8.69e-02 | tk = 5.10e+02
#     f(xk): 1.56387e+04 | f(prox): 1.79140e+04
#     Improvement from line search | f(prox_ls): 1.53842e+04
# [ 16]: fk = 1.54e+04 | error = 2.27e+02 | deltak = 8.60e-02 | tk = 5.15e+02
#     f(xk): 1.53842e+04 | f(prox): 1.73904e+04
#     Improvement from line search | f(prox_ls): 1.53353e+04
# [ 17]: fk = 1.53e+04 | error = 2.27e+02 | deltak = 8.51e-02 | tk = 5.10e+02
#     f(xk): 1.53353e+04 | f(prox): 1.76431e+04
#     Improvement from line search | f(prox_ls): 1.52130e+04
# [ 18]: fk = 1.52e+04 | error = 2.28e+02 | deltak = 8.43e-02 | tk = 5.15e+02
#     f(xk): 1.52130e+04 | f(prox): 1.76438e+04
#     Improvement from line search | f(prox_ls): 1.52130e+04
# [ 19]: fk = 1.52e+04 | error = 2.28e+02 | deltak = 8.35e-02 | tk = 5.10e+02
#     f(xk): 1.52130e+04 | f(prox): 1.79613e+04
#     Improvement from line search | f(prox_ls): 1.47772e+04
# [ 20]: fk = 1.48e+04 | error = 2.27e+02 | deltak = 8.26e-02 | tk = 5.15e+02
#     f(xk): 1.47772e+04 | f(prox): 1.64951e+04
#     Improvement from line search | f(prox_ls): 1.43995e+04
# [ 21]: fk = 1.44e+04 | error = 2.26e+02 | deltak = 8.18e-02 | tk = 5.10e+02
#     f(xk): 1.43995e+04 | f(prox): 1.79706e+04
#     Improvement from line search | f(prox_ls): 1.43937e+04
# [ 22]: fk = 1.44e+04 | error = 2.26e+02 | deltak = 8.10e-02 | tk = 5.04e+02
#     f(xk): 1.43937e+04 | f(prox): 1.73723e+04
#     Improvement from line search | f(prox_ls): 1.42912e+04
# [ 23]: fk = 1.43e+04 | error = 2.26e+02 | deltak = 8.02e-02 | tk = 5.10e+02
#     f(xk): 1.42912e+04 | f(prox): 1.66895e+04
#     Improvement from line search | f(prox_ls): 1.42244e+04
# [ 24]: fk = 1.42e+04 | error = 2.26e+02 | deltak = 7.94e-02 | tk = 5.04e+02
#     f(xk): 1.42244e+04 | f(prox): 1.70923e+04
#     Improvement from line search | f(prox_ls): 1.41821e+04
# [ 25]: fk = 1.42e+04 | error = 2.26e+02 | deltak = 7.86e-02 | tk = 5.09e+02
#     f(xk): 1.41821e+04 | f(prox): 1.65005e+04
#     Improvement from line search | f(prox_ls): 1.41805e+04
# [ 26]: fk = 1.42e+04 | error = 2.26e+02 | deltak = 7.78e-02 | tk = 5.04e+02
#     f(xk): 1.41805e+04 | f(prox): 1.67650e+04
#     Improvement from line search | f(prox_ls): 1.41826e+04
# [ 27]: fk = 1.42e+04 | error = 2.26e+02 | deltak = 7.70e-02 | tk = 5.09e+02
#     f(xk): 1.41826e+04 | f(prox): 1.69204e+04
#     Improvement from line search | f(prox_ls): 1.40218e+04
# [ 28]: fk = 1.40e+04 | error = 2.26e+02 | deltak = 7.62e-02 | tk = 5.15e+02
#     f(xk): 1.40218e+04 | f(prox): 1.65352e+04
#     Improvement from line search | f(prox_ls): 1.40227e+04
# [ 29]: fk = 1.40e+04 | error = 2.26e+02 | deltak = 7.55e-02 | tk = 5.09e+02
#     f(xk): 1.40227e+04 | f(prox): 1.72623e+04
#     Improvement from line search | f(prox_ls): 1.40008e+04
# [ 30]: fk = 1.40e+04 | error = 2.26e+02 | deltak = 7.47e-02 | tk = 5.14e+02
#     f(xk): 1.40008e+04 | f(prox): 1.66180e+04
#     Improvement from line search | f(prox_ls): 1.39959e+04
# [ 31]: fk = 1.40e+04 | error = 2.26e+02 | deltak = 7.40e-02 | tk = 5.09e+02
#     f(xk): 1.39959e+04 | f(prox): 1.59906e+04
#     Improvement from line search | f(prox_ls): 1.35000e+04
# [ 32]: fk = 1.35e+04 | error = 2.25e+02 | deltak = 7.32e-02 | tk = 5.14e+02
#     f(xk): 1.35000e+04 | f(prox): 1.68569e+04
#     Improvement from line search | f(prox_ls): 1.34364e+04
# [ 33]: fk = 1.34e+04 | error = 2.25e+02 | deltak = 7.25e-02 | tk = 5.09e+02
#     f(xk): 1.34364e+04 | f(prox): 1.69045e+04
#     Improvement from line search | f(prox_ls): 1.34049e+04
# [ 34]: fk = 1.34e+04 | error = 2.25e+02 | deltak = 7.18e-02 | tk = 5.04e+02
#     f(xk): 1.34049e+04 | f(prox): 1.69332e+04
#     Improvement from line search | f(prox_ls): 1.34003e+04
# [ 35]: fk = 1.34e+04 | error = 2.25e+02 | deltak = 7.11e-02 | tk = 4.99e+02
#     f(xk): 1.34003e+04 | f(prox): 1.68628e+04
#     Improvement from line search | f(prox_ls): 1.30691e+04
# [ 36]: fk = 1.31e+04 | error = 2.25e+02 | deltak = 7.03e-02 | tk = 5.04e+02
#     f(xk): 1.30691e+04 | f(prox): 1.70432e+04
#     Improvement from line search | f(prox_ls): 1.30625e+04
# [ 37]: fk = 1.31e+04 | error = 2.25e+02 | deltak = 6.96e-02 | tk = 4.99e+02
#     f(xk): 1.30625e+04 | f(prox): 1.70792e+04
#     Improvement from line search | f(prox_ls): 1.29242e+04
# [ 38]: fk = 1.29e+04 | error = 2.25e+02 | deltak = 6.89e-02 | tk = 5.04e+02
#     f(xk): 1.29242e+04 | f(prox): 1.69903e+04
#     Improvement from line search | f(prox_ls): 1.26572e+04
# [ 39]: fk = 1.27e+04 | error = 2.25e+02 | deltak = 6.83e-02 | tk = 5.09e+02
#     f(xk): 1.26572e+04 | f(prox): 1.60134e+04
#     Improvement from line search | f(prox_ls): 1.24721e+04
# [ 40]: fk = 1.25e+04 | error = 2.25e+02 | deltak = 6.76e-02 | tk = 5.04e+02
#     f(xk): 1.24721e+04 | f(prox): 1.66317e+04
#     Improvement from line search | f(prox_ls): 1.24524e+04
# [ 41]: fk = 1.25e+04 | error = 2.25e+02 | deltak = 6.69e-02 | tk = 4.99e+02
#     f(xk): 1.24524e+04 | f(prox): 1.62079e+04
#     Improvement from line search | f(prox_ls): 1.24467e+04
# [ 42]: fk = 1.24e+04 | error = 2.26e+02 | deltak = 6.62e-02 | tk = 4.94e+02
#     f(xk): 1.24467e+04 | f(prox): 1.74628e+04
#     Improvement from line search | f(prox_ls): 1.23805e+04
# [ 43]: fk = 1.24e+04 | error = 2.26e+02 | deltak = 6.56e-02 | tk = 4.99e+02
#     f(xk): 1.23805e+04 | f(prox): 1.67373e+04
#     Improvement from line search | f(prox_ls): 1.22852e+04
# [ 44]: fk = 1.23e+04 | error = 2.26e+02 | deltak = 6.49e-02 | tk = 5.04e+02
#     f(xk): 1.22852e+04 | f(prox): 1.74743e+04
#     Improvement from line search | f(prox_ls): 1.22102e+04
# [ 45]: fk = 1.22e+04 | error = 2.26e+02 | deltak = 6.43e-02 | tk = 5.09e+02
#     f(xk): 1.22102e+04 | f(prox): 1.64994e+04
#     Improvement from line search | f(prox_ls): 1.21947e+04
# [ 46]: fk = 1.22e+04 | error = 2.26e+02 | deltak = 6.36e-02 | tk = 5.04e+02
#     f(xk): 1.21947e+04 | f(prox): 1.63458e+04
#     Improvement from line search | f(prox_ls): 1.21883e+04
# [ 47]: fk = 1.22e+04 | error = 2.26e+02 | deltak = 6.30e-02 | tk = 4.99e+02
#     f(xk): 1.21883e+04 | f(prox): 1.72580e+04
#     Improvement from line search | f(prox_ls): 1.20838e+04
# [ 48]: fk = 1.21e+04 | error = 2.25e+02 | deltak = 6.24e-02 | tk = 5.04e+02
#     f(xk): 1.20838e+04 | f(prox): 1.71075e+04
#     Improvement from line search | f(prox_ls): 1.20776e+04
# [ 49]: fk = 1.21e+04 | error = 2.25e+02 | deltak = 6.17e-02 | tk = 4.99e+02
#     f(xk): 1.20776e+04 | f(prox): 1.65950e+04
#     Improvement from line search | f(prox_ls): 1.20438e+04
# [ 50]: fk = 1.20e+04 | error = 2.25e+02 | deltak = 6.11e-02 | tk = 5.04e+02
#     f(xk): 1.20438e+04 | f(prox): 1.57463e+04
#     Improvement from line search | f(prox_ls): 1.18134e+04
# [ 51]: fk = 1.18e+04 | error = 2.26e+02 | deltak = 6.05e-02 | tk = 5.09e+02
#     f(xk): 1.18134e+04 | f(prox): 1.60095e+04
#     Improvement from line search | f(prox_ls): 1.17846e+04
# [ 52]: fk = 1.18e+04 | error = 2.26e+02 | deltak = 5.99e-02 | tk = 5.04e+02
#     f(xk): 1.17846e+04 | f(prox): 1.69557e+04
#     Improvement from line search | f(prox_ls): 1.17641e+04
# [ 53]: fk = 1.18e+04 | error = 2.25e+02 | deltak = 5.93e-02 | tk = 5.09e+02
#     f(xk): 1.17641e+04 | f(prox): 1.69221e+04
#     Improvement from line search | f(prox_ls): 1.16587e+04
# [ 54]: fk = 1.17e+04 | error = 2.26e+02 | deltak = 5.87e-02 | tk = 5.14e+02
#     f(xk): 1.16587e+04 | f(prox): 1.66647e+04
#     Improvement from line search | f(prox_ls): 1.16587e+04
# [ 55]: fk = 1.17e+04 | error = 2.26e+02 | deltak = 5.81e-02 | tk = 5.09e+02
#     f(xk): 1.16587e+04 | f(prox): 1.59122e+04
#     Improvement from line search | f(prox_ls): 1.16461e+04
# [ 56]: fk = 1.16e+04 | error = 2.26e+02 | deltak = 5.75e-02 | tk = 5.14e+02
#     f(xk): 1.16461e+04 | f(prox): 1.70757e+04
#     Improvement from line search | f(prox_ls): 1.14990e+04
# [ 57]: fk = 1.15e+04 | error = 2.26e+02 | deltak = 5.70e-02 | tk = 5.19e+02
#     f(xk): 1.14990e+04 | f(prox): 1.72622e+04
#     Improvement from line search | f(prox_ls): 1.14929e+04
# [ 58]: fk = 1.15e+04 | error = 2.26e+02 | deltak = 5.64e-02 | tk = 5.14e+02
#     f(xk): 1.14929e+04 | f(prox): 1.69063e+04
#     Improvement from line search | f(prox_ls): 1.14418e+04
# [ 59]: fk = 1.14e+04 | error = 2.26e+02 | deltak = 5.58e-02 | tk = 5.19e+02
#     f(xk): 1.14418e+04 | f(prox): 1.68931e+04
#     Improvement from line search | f(prox_ls): 1.14384e+04
# [ 60]: fk = 1.14e+04 | error = 2.26e+02 | deltak = 5.53e-02 | tk = 5.14e+02
#     f(xk): 1.14384e+04 | f(prox): 1.71807e+04
#     Improvement from line search | f(prox_ls): 1.14396e+04
# [ 61]: fk = 1.14e+04 | error = 2.26e+02 | deltak = 5.47e-02 | tk = 5.19e+02
#     f(xk): 1.14396e+04 | f(prox): 1.71442e+04
#     Improvement from line search | f(prox_ls): 1.10379e+04
# [ 62]: fk = 1.10e+04 | error = 2.25e+02 | deltak = 5.42e-02 | tk = 5.24e+02
#     f(xk): 1.10379e+04 | f(prox): 1.65640e+04
#     Improvement from line search | f(prox_ls): 1.09591e+04
# [ 63]: fk = 1.10e+04 | error = 2.26e+02 | deltak = 5.36e-02 | tk = 5.19e+02
#     f(xk): 1.09591e+04 | f(prox): 1.68197e+04
#     Improvement from line search | f(prox_ls): 1.09014e+04
# [ 64]: fk = 1.09e+04 | error = 2.26e+02 | deltak = 5.31e-02 | tk = 5.24e+02
#     f(xk): 1.09014e+04 | f(prox): 1.61380e+04
#     Improvement from line search | f(prox_ls): 1.08773e+04
# [ 65]: fk = 1.09e+04 | error = 2.26e+02 | deltak = 5.26e-02 | tk = 5.19e+02
#     f(xk): 1.08773e+04 | f(prox): 1.66531e+04
#     Improvement from line search | f(prox_ls): 1.08539e+04
# [ 66]: fk = 1.09e+04 | error = 2.25e+02 | deltak = 5.20e-02 | tk = 5.24e+02
#     f(xk): 1.08539e+04 | f(prox): 1.61987e+04
#     Improvement from line search | f(prox_ls): 1.08288e+04
# [ 67]: fk = 1.08e+04 | error = 2.25e+02 | deltak = 5.15e-02 | tk = 5.29e+02
#     f(xk): 1.08288e+04 | f(prox): 1.61755e+04
#     Improvement from line search | f(prox_ls): 1.08256e+04
# [ 68]: fk = 1.08e+04 | error = 2.25e+02 | deltak = 5.10e-02 | tk = 5.24e+02
#     f(xk): 1.08256e+04 | f(prox): 1.59511e+04
#     Improvement from line search | f(prox_ls): 1.08224e+04
# [ 69]: fk = 1.08e+04 | error = 2.25e+02 | deltak = 5.05e-02 | tk = 5.29e+02
#     f(xk): 1.08224e+04 | f(prox): 1.68475e+04
#     Improvement from line search | f(prox_ls): 1.07960e+04
# [ 70]: fk = 1.08e+04 | error = 2.25e+02 | deltak = 5.00e-02 | tk = 5.34e+02
#     f(xk): 1.07960e+04 | f(prox): 1.64664e+04
#     Improvement from line search | f(prox_ls): 1.07758e+04
# [ 71]: fk = 1.08e+04 | error = 2.25e+02 | deltak = 4.95e-02 | tk = 5.40e+02
#     f(xk): 1.07758e+04 | f(prox): 1.60728e+04
#     Improvement from line search | f(prox_ls): 1.07734e+04
# [ 72]: fk = 1.08e+04 | error = 2.25e+02 | deltak = 4.90e-02 | tk = 5.34e+02
#     f(xk): 1.07734e+04 | f(prox): 1.61200e+04
#     Improvement from line search | f(prox_ls): 1.07580e+04
# [ 73]: fk = 1.08e+04 | error = 2.25e+02 | deltak = 4.85e-02 | tk = 5.40e+02
#     f(xk): 1.07580e+04 | f(prox): 1.41324e+04
#     Improvement from line search | f(prox_ls): 1.07425e+04
# [ 74]: fk = 1.07e+04 | error = 2.25e+02 | deltak = 4.80e-02 | tk = 5.45e+02
#     f(xk): 1.07425e+04 | f(prox): 1.64486e+04
#     Improvement from line search | f(prox_ls): 1.07254e+04
# [ 75]: fk = 1.07e+04 | error = 2.25e+02 | deltak = 4.75e-02 | tk = 5.51e+02
#     f(xk): 1.07254e+04 | f(prox): 1.60013e+04
#     Improvement from line search | f(prox_ls): 1.06729e+04
# [ 76]: fk = 1.07e+04 | error = 2.25e+02 | deltak = 4.71e-02 | tk = 5.56e+02
#     f(xk): 1.06729e+04 | f(prox): 1.71104e+04
#     Improvement from line search | f(prox_ls): 1.06206e+04
# [ 77]: fk = 1.06e+04 | error = 2.25e+02 | deltak = 4.66e-02 | tk = 5.62e+02
#     f(xk): 1.06206e+04 | f(prox): 1.58977e+04
#     Improvement from line search | f(prox_ls): 1.06193e+04
# [ 78]: fk = 1.06e+04 | error = 2.25e+02 | deltak = 4.61e-02 | tk = 5.56e+02
#     f(xk): 1.06193e+04 | f(prox): 1.65662e+04
#     Improvement from line search | f(prox_ls): 1.04865e+04
# [ 79]: fk = 1.05e+04 | error = 2.25e+02 | deltak = 4.57e-02 | tk = 5.62e+02
#     f(xk): 1.04865e+04 | f(prox): 1.67898e+04
#     Improvement from line search | f(prox_ls): 1.04831e+04
# [ 80]: fk = 1.05e+04 | error = 2.25e+02 | deltak = 4.52e-02 | tk = 5.56e+02
#     f(xk): 1.04831e+04 | f(prox): 1.65816e+04
#     Improvement from line search | f(prox_ls): 1.04576e+04
# [ 81]: fk = 1.05e+04 | error = 2.25e+02 | deltak = 4.48e-02 | tk = 5.62e+02
#     f(xk): 1.04576e+04 | f(prox): 1.62974e+04
#     Improvement from line search | f(prox_ls): 1.04224e+04
# [ 82]: fk = 1.04e+04 | error = 2.25e+02 | deltak = 4.43e-02 | tk = 5.67e+02
#     f(xk): 1.04224e+04 | f(prox): 1.62385e+04
#     Improvement from line search | f(prox_ls): 1.03246e+04
# [ 83]: fk = 1.03e+04 | error = 2.25e+02 | deltak = 4.39e-02 | tk = 5.73e+02
#     f(xk): 1.03246e+04 | f(prox): 1.58395e+04
#     Improvement from line search | f(prox_ls): 1.03096e+04
# [ 84]: fk = 1.03e+04 | error = 2.25e+02 | deltak = 4.34e-02 | tk = 5.67e+02
#     f(xk): 1.03096e+04 | f(prox): 1.67972e+04
#     Improvement from line search | f(prox_ls): 1.02686e+04
# [ 85]: fk = 1.03e+04 | error = 2.25e+02 | deltak = 4.30e-02 | tk = 5.73e+02
#     f(xk): 1.02686e+04 | f(prox): 1.58760e+04
#     Improvement from line search | f(prox_ls): 1.02637e+04
# [ 86]: fk = 1.03e+04 | error = 2.25e+02 | deltak = 4.26e-02 | tk = 5.67e+02
#     f(xk): 1.02637e+04 | f(prox): 1.66967e+04
#     Improvement from line search | f(prox_ls): 1.02566e+04
# [ 87]: fk = 1.03e+04 | error = 2.25e+02 | deltak = 4.21e-02 | tk = 5.73e+02
#     f(xk): 1.02566e+04 | f(prox): 1.54033e+04
#     Improvement from line search | f(prox_ls): 1.02537e+04
# [ 88]: fk = 1.03e+04 | error = 2.25e+02 | deltak = 4.17e-02 | tk = 5.78e+02
#     f(xk): 1.02537e+04 | f(prox): 1.66898e+04
#     Improvement from line search | f(prox_ls): 1.02493e+04
# [ 89]: fk = 1.02e+04 | error = 2.25e+02 | deltak = 4.13e-02 | tk = 5.84e+02
#     f(xk): 1.02493e+04 | f(prox): 1.62257e+04
#     Improvement from line search | f(prox_ls): 1.02489e+04
# [ 90]: fk = 1.02e+04 | error = 2.25e+02 | deltak = 4.09e-02 | tk = 5.90e+02
#     f(xk): 1.02489e+04 | f(prox): 1.67121e+04
#     Improvement from line search | f(prox_ls): 1.02128e+04
# [ 91]: fk = 1.02e+04 | error = 2.25e+02 | deltak = 4.05e-02 | tk = 5.96e+02
#     f(xk): 1.02128e+04 | f(prox): 1.66183e+04
#     Improvement from line search | f(prox_ls): 1.01990e+04
# [ 92]: fk = 1.02e+04 | error = 2.26e+02 | deltak = 4.01e-02 | tk = 6.02e+02
#     f(xk): 1.01990e+04 | f(prox): 1.70235e+04
#     Improvement from line search | f(prox_ls): 1.01766e+04
# [ 93]: fk = 1.02e+04 | error = 2.25e+02 | deltak = 3.97e-02 | tk = 6.08e+02
#     f(xk): 1.01766e+04 | f(prox): 1.65946e+04
#     Improvement from line search | f(prox_ls): 1.01532e+04
# [ 94]: fk = 1.02e+04 | error = 2.25e+02 | deltak = 3.93e-02 | tk = 6.14e+02
#     f(xk): 1.01532e+04 | f(prox): 1.69050e+04
#     Improvement from line search | f(prox_ls): 1.00790e+04
# [ 95]: fk = 1.01e+04 | error = 2.26e+02 | deltak = 3.89e-02 | tk = 6.20e+02
#     f(xk): 1.00790e+04 | f(prox): 1.63547e+04
#     Improvement from line search | f(prox_ls): 1.00672e+04
# [ 96]: fk = 1.01e+04 | error = 2.26e+02 | deltak = 3.85e-02 | tk = 6.14e+02
#     f(xk): 1.00672e+04 | f(prox): 1.67263e+04
#     Improvement from line search | f(prox_ls): 9.87587e+03
# [ 97]: fk = 9.88e+03 | error = 2.25e+02 | deltak = 3.81e-02 | tk = 6.20e+02
#     f(xk): 9.87587e+03 | f(prox): 1.61066e+04
#     Improvement from line search | f(prox_ls): 9.86898e+03
# [ 98]: fk = 9.87e+03 | error = 2.25e+02 | deltak = 3.77e-02 | tk = 6.14e+02
#     f(xk): 9.86898e+03 | f(prox): 1.61834e+04
#     Improvement from line search | f(prox_ls): 9.86718e+03
# [ 99]: fk = 9.87e+03 | error = 2.25e+02 | deltak = 3.73e-02 | tk = 6.20e+02
#     f(xk): 9.86718e+03 | f(prox): 1.64668e+04
#     Improvement from line search | f(prox_ls): 9.80194e+03
# [100]: fk = 9.80e+03 | error = 2.25e+02 | deltak = 3.70e-02 | tk = 6.26e+02
#     f(xk): 9.80194e+03 | f(prox): 1.67396e+04
#     Improvement from line search | f(prox_ls): 9.75961e+03
# [101]: fk = 9.76e+03 | error = 2.25e+02 | deltak = 3.66e-02 | tk = 6.20e+02
#     f(xk): 9.75961e+03 | f(prox): 1.68010e+04
#     Improvement from line search | f(prox_ls): 9.75315e+03
# [102]: fk = 9.75e+03 | error = 2.25e+02 | deltak = 3.62e-02 | tk = 6.14e+02
#     f(xk): 9.75315e+03 | f(prox): 1.57465e+04
#     Improvement from line search | f(prox_ls): 9.75532e+03
# [103]: fk = 9.76e+03 | error = 2.25e+02 | deltak = 3.59e-02 | tk = 6.20e+02
#     f(xk): 9.75532e+03 | f(prox): 1.65594e+04
#     Improvement from line search | f(prox_ls): 9.74608e+03
# [104]: fk = 9.75e+03 | error = 2.25e+02 | deltak = 3.55e-02 | tk = 6.26e+02
#     f(xk): 9.74608e+03 | f(prox): 1.63807e+04
#     Improvement from line search | f(prox_ls): 9.53068e+03
# [105]: fk = 9.53e+03 | error = 2.26e+02 | deltak = 3.52e-02 | tk = 6.32e+02
#     f(xk): 9.53068e+03 | f(prox): 1.64981e+04
#     Improvement from line search | f(prox_ls): 9.49974e+03
# [106]: fk = 9.50e+03 | error = 2.25e+02 | deltak = 3.48e-02 | tk = 6.26e+02
#     f(xk): 9.49974e+03 | f(prox): 1.66581e+04
#     Improvement from line search | f(prox_ls): 9.46825e+03
# [107]: fk = 9.47e+03 | error = 2.25e+02 | deltak = 3.45e-02 | tk = 6.32e+02
#     f(xk): 9.46825e+03 | f(prox): 1.53774e+04
#     Improvement from line search | f(prox_ls): 9.46498e+03
# [108]: fk = 9.46e+03 | error = 2.25e+02 | deltak = 3.41e-02 | tk = 6.26e+02
#     f(xk): 9.46498e+03 | f(prox): 1.64656e+04
#     Improvement from line search | f(prox_ls): 9.43429e+03
# [109]: fk = 9.43e+03 | error = 2.25e+02 | deltak = 3.38e-02 | tk = 6.32e+02
#     f(xk): 9.43429e+03 | f(prox): 1.67577e+04
#     Improvement from line search | f(prox_ls): 9.42934e+03
# [110]: fk = 9.43e+03 | error = 2.25e+02 | deltak = 3.34e-02 | tk = 6.26e+02
#     f(xk): 9.42934e+03 | f(prox): 1.60206e+04
#     Improvement from line search | f(prox_ls): 9.42971e+03
# [111]: fk = 9.43e+03 | error = 2.25e+02 | deltak = 3.31e-02 | tk = 6.32e+02
#     f(xk): 9.42971e+03 | f(prox): 1.59587e+04
#     Improvement from line search | f(prox_ls): 9.43030e+03
# [112]: fk = 9.43e+03 | error = 2.25e+02 | deltak = 3.28e-02 | tk = 6.38e+02
#     f(xk): 9.43030e+03 | f(prox): 1.69115e+04
#     Improvement from line search | f(prox_ls): 9.42929e+03
# [113]: fk = 9.43e+03 | error = 2.25e+02 | deltak = 3.24e-02 | tk = 6.45e+02
#     f(xk): 9.42929e+03 | f(prox): 1.62763e+04
#     Improvement from line search | f(prox_ls): 9.33885e+03
# [114]: fk = 9.34e+03 | error = 2.25e+02 | deltak = 3.21e-02 | tk = 6.51e+02
#     f(xk): 9.33885e+03 | f(prox): 1.56044e+04
#     Improvement from line search | f(prox_ls): 9.30508e+03
# [115]: fk = 9.31e+03 | error = 2.25e+02 | deltak = 3.18e-02 | tk = 6.45e+02
#     f(xk): 9.30508e+03 | f(prox): 1.61013e+04
#     Improvement from line search | f(prox_ls): 9.26531e+03
# [116]: fk = 9.27e+03 | error = 2.25e+02 | deltak = 3.15e-02 | tk = 6.51e+02
#     f(xk): 9.26531e+03 | f(prox): 1.65723e+04
#     Improvement from line search | f(prox_ls): 9.26173e+03
# [117]: fk = 9.26e+03 | error = 2.25e+02 | deltak = 3.12e-02 | tk = 6.45e+02
#     f(xk): 9.26173e+03 | f(prox): 1.63755e+04
#     Improvement from line search | f(prox_ls): 9.21304e+03
# [118]: fk = 9.21e+03 | error = 2.25e+02 | deltak = 3.09e-02 | tk = 6.51e+02
#     f(xk): 9.21304e+03 | f(prox): 1.67066e+04
#     Improvement from line search | f(prox_ls): 9.21208e+03
# [119]: fk = 9.21e+03 | error = 2.25e+02 | deltak = 3.05e-02 | tk = 6.45e+02
#     f(xk): 9.21208e+03 | f(prox): 1.51747e+04
#     Improvement from line search | f(prox_ls): 9.20765e+03
# [120]: fk = 9.21e+03 | error = 2.25e+02 | deltak = 3.02e-02 | tk = 6.51e+02
#     f(xk): 9.20765e+03 | f(prox): 1.66349e+04
#     Improvement from line search | f(prox_ls): 9.08754e+03
# [121]: fk = 9.09e+03 | error = 2.25e+02 | deltak = 2.99e-02 | tk = 6.58e+02
#     f(xk): 9.08754e+03 | f(prox): 1.59824e+04
#     Improvement from line search | f(prox_ls): 9.07097e+03
# [122]: fk = 9.07e+03 | error = 2.25e+02 | deltak = 2.96e-02 | tk = 6.51e+02
#     f(xk): 9.07097e+03 | f(prox): 1.62858e+04
#     Improvement from line search | f(prox_ls): 8.98493e+03
# [123]: fk = 8.98e+03 | error = 2.25e+02 | deltak = 2.93e-02 | tk = 6.58e+02
#     f(xk): 8.98493e+03 | f(prox): 1.58373e+04
#     Improvement from line search | f(prox_ls): 8.85293e+03
# [124]: fk = 8.85e+03 | error = 2.25e+02 | deltak = 2.90e-02 | tk = 6.64e+02
#     f(xk): 8.85293e+03 | f(prox): 1.62835e+04
#     Improvement from line search | f(prox_ls): 8.83491e+03
# [125]: fk = 8.83e+03 | error = 2.25e+02 | deltak = 2.88e-02 | tk = 6.57e+02
#     f(xk): 8.83491e+03 | f(prox): 1.62945e+04
#     Improvement from line search | f(prox_ls): 8.83231e+03
# [126]: fk = 8.83e+03 | error = 2.25e+02 | deltak = 2.85e-02 | tk = 6.51e+02
#     f(xk): 8.83231e+03 | f(prox): 1.50552e+04
#     Improvement from line search | f(prox_ls): 8.82629e+03
# [127]: fk = 8.83e+03 | error = 2.25e+02 | deltak = 2.82e-02 | tk = 6.57e+02
#     f(xk): 8.82629e+03 | f(prox): 1.58846e+04
#     Improvement from line search | f(prox_ls): 8.82584e+03
# [128]: fk = 8.83e+03 | error = 2.25e+02 | deltak = 2.79e-02 | tk = 6.64e+02
#     f(xk): 8.82584e+03 | f(prox): 1.56816e+04
#     Improvement from line search | f(prox_ls): 8.74404e+03
# [129]: fk = 8.74e+03 | error = 2.25e+02 | deltak = 2.76e-02 | tk = 6.71e+02
#     f(xk): 8.74404e+03 | f(prox): 1.64864e+04
#     Improvement from line search | f(prox_ls): 8.71139e+03
# [130]: fk = 8.71e+03 | error = 2.25e+02 | deltak = 2.73e-02 | tk = 6.64e+02
#     f(xk): 8.71139e+03 | f(prox): 1.67771e+04
#     Improvement from line search | f(prox_ls): 8.70837e+03
# [131]: fk = 8.71e+03 | error = 2.25e+02 | deltak = 2.71e-02 | tk = 6.57e+02
#     f(xk): 8.70837e+03 | f(prox): 1.66352e+04
#     Improvement from line search | f(prox_ls): 8.70785e+03
# [132]: fk = 8.71e+03 | error = 2.25e+02 | deltak = 2.68e-02 | tk = 6.64e+02
#     f(xk): 8.70785e+03 | f(prox): 1.62366e+04
#     Improvement from line search | f(prox_ls): 8.70749e+03
# [133]: fk = 8.71e+03 | error = 2.25e+02 | deltak = 2.65e-02 | tk = 6.70e+02
#     f(xk): 8.70749e+03 | f(prox): 1.64328e+04
#     Improvement from line search | f(prox_ls): 8.68468e+03
# [134]: fk = 8.68e+03 | error = 2.25e+02 | deltak = 2.63e-02 | tk = 6.77e+02
#     f(xk): 8.68468e+03 | f(prox): 1.63269e+04
#     Improvement from line search | f(prox_ls): 8.66264e+03
# [135]: fk = 8.66e+03 | error = 2.25e+02 | deltak = 2.60e-02 | tk = 6.84e+02
#     f(xk): 8.66264e+03 | f(prox): 1.62592e+04
#     Improvement from line search | f(prox_ls): 8.58532e+03
# [136]: fk = 8.59e+03 | error = 2.25e+02 | deltak = 2.57e-02 | tk = 6.91e+02
#     f(xk): 8.58532e+03 | f(prox): 1.61518e+04
#     Improvement from line search | f(prox_ls): 8.58467e+03
# [137]: fk = 8.58e+03 | error = 2.24e+02 | deltak = 2.55e-02 | tk = 6.84e+02
#     f(xk): 8.58467e+03 | f(prox): 1.65076e+04
#     Improvement from line search | f(prox_ls): 8.55637e+03
# [138]: fk = 8.56e+03 | error = 2.25e+02 | deltak = 2.52e-02 | tk = 6.91e+02
#     f(xk): 8.55637e+03 | f(prox): 1.58083e+04
#     Improvement from line search | f(prox_ls): 8.55809e+03
# [139]: fk = 8.56e+03 | error = 2.25e+02 | deltak = 2.50e-02 | tk = 6.84e+02
#     f(xk): 8.55809e+03 | f(prox): 1.59333e+04
#     Improvement from line search | f(prox_ls): 8.56005e+03
# [140]: fk = 8.56e+03 | error = 2.24e+02 | deltak = 2.47e-02 | tk = 6.91e+02
#     f(xk): 8.56005e+03 | f(prox): 1.61266e+04
#     Improvement from line search | f(prox_ls): 8.55965e+03
# [141]: fk = 8.56e+03 | error = 2.24e+02 | deltak = 2.45e-02 | tk = 6.98e+02
#     f(xk): 8.55965e+03 | f(prox): 1.61671e+04
#     Improvement from line search | f(prox_ls): 8.52909e+03
# [142]: fk = 8.53e+03 | error = 2.24e+02 | deltak = 2.42e-02 | tk = 7.05e+02
#     f(xk): 8.52909e+03 | f(prox): 1.53083e+04
#     Improvement from line search | f(prox_ls): 8.52954e+03
# [143]: fk = 8.53e+03 | error = 2.24e+02 | deltak = 2.40e-02 | tk = 6.98e+02
#     f(xk): 8.52954e+03 | f(prox): 1.55635e+04
#     Improvement from line search | f(prox_ls): 8.52790e+03
# [144]: fk = 8.53e+03 | error = 2.24e+02 | deltak = 2.38e-02 | tk = 7.04e+02
#     f(xk): 8.52790e+03 | f(prox): 1.61645e+04
#     Improvement from line search | f(prox_ls): 8.52214e+03
# [145]: fk = 8.52e+03 | error = 2.24e+02 | deltak = 2.35e-02 | tk = 7.12e+02
#     f(xk): 8.52214e+03 | f(prox): 1.66035e+04
#     Improvement from line search | f(prox_ls): 8.46182e+03
# [146]: fk = 8.46e+03 | error = 2.24e+02 | deltak = 2.33e-02 | tk = 7.19e+02
#     f(xk): 8.46182e+03 | f(prox): 1.61187e+04
#     Improvement from line search | f(prox_ls): 8.46338e+03
# [147]: fk = 8.46e+03 | error = 2.24e+02 | deltak = 2.31e-02 | tk = 7.11e+02
#     f(xk): 8.46338e+03 | f(prox): 1.61568e+04
#     Improvement from line search | f(prox_ls): 8.46430e+03
# [148]: fk = 8.46e+03 | error = 2.24e+02 | deltak = 2.28e-02 | tk = 7.19e+02
#     f(xk): 8.46430e+03 | f(prox): 1.58061e+04
#     Improvement from line search | f(prox_ls): 8.44545e+03
# [149]: fk = 8.45e+03 | error = 2.24e+02 | deltak = 2.26e-02 | tk = 7.26e+02
#     f(xk): 8.44545e+03 | f(prox): 1.57040e+04
#     Improvement from line search | f(prox_ls): 8.43525e+03
# [150]: fk = 8.44e+03 | error = 2.24e+02 | deltak = 2.24e-02 | tk = 7.33e+02
#     f(xk): 8.43525e+03 | f(prox): 1.58333e+04
#     Improvement from line search | f(prox_ls): 8.43298e+03
# [151]: fk = 8.43e+03 | error = 2.24e+02 | deltak = 2.21e-02 | tk = 7.26e+02
#     f(xk): 8.43298e+03 | f(prox): 1.57706e+04
#     Improvement from line search | f(prox_ls): 8.37357e+03
# [152]: fk = 8.37e+03 | error = 2.24e+02 | deltak = 2.19e-02 | tk = 7.33e+02
#     f(xk): 8.37357e+03 | f(prox): 1.64942e+04
#     Improvement from line search | f(prox_ls): 8.36158e+03
# [153]: fk = 8.36e+03 | error = 2.24e+02 | deltak = 2.17e-02 | tk = 7.26e+02
#     f(xk): 8.36158e+03 | f(prox): 1.58959e+04
#     Improvement from line search | f(prox_ls): 8.34100e+03
# [154]: fk = 8.34e+03 | error = 2.24e+02 | deltak = 2.15e-02 | tk = 7.33e+02
#     f(xk): 8.34100e+03 | f(prox): 1.60610e+04
#     Improvement from line search | f(prox_ls): 8.33608e+03
# [155]: fk = 8.34e+03 | error = 2.24e+02 | deltak = 2.13e-02 | tk = 7.26e+02
#     f(xk): 8.33608e+03 | f(prox): 1.63775e+04
#     Improvement from line search | f(prox_ls): 8.30689e+03
# [156]: fk = 8.31e+03 | error = 2.24e+02 | deltak = 2.11e-02 | tk = 7.33e+02
#     f(xk): 8.30689e+03 | f(prox): 1.60029e+04
#     Improvement from line search | f(prox_ls): 8.30652e+03
# [157]: fk = 8.31e+03 | error = 2.24e+02 | deltak = 2.08e-02 | tk = 7.25e+02
#     f(xk): 8.30652e+03 | f(prox): 1.58106e+04
#     Improvement from line search | f(prox_ls): 8.24804e+03
# [158]: fk = 8.25e+03 | error = 2.24e+02 | deltak = 2.06e-02 | tk = 7.33e+02
#     f(xk): 8.24804e+03 | f(prox): 1.62313e+04
#     Improvement from line search | f(prox_ls): 8.22917e+03
# [159]: fk = 8.23e+03 | error = 2.24e+02 | deltak = 2.04e-02 | tk = 7.25e+02
#     f(xk): 8.22917e+03 | f(prox): 1.59418e+04
#     Improvement from line search | f(prox_ls): 8.22404e+03
# [160]: fk = 8.22e+03 | error = 2.24e+02 | deltak = 2.02e-02 | tk = 7.18e+02
#     f(xk): 8.22404e+03 | f(prox): 1.59484e+04
#     Improvement from line search | f(prox_ls): 8.22223e+03
# [161]: fk = 8.22e+03 | error = 2.24e+02 | deltak = 2.00e-02 | tk = 7.25e+02
#     f(xk): 8.22223e+03 | f(prox): 1.62259e+04
#     Improvement from line search | f(prox_ls): 8.22154e+03
# [162]: fk = 8.22e+03 | error = 2.24e+02 | deltak = 1.98e-02 | tk = 7.33e+02
#     f(xk): 8.22154e+03 | f(prox): 1.59408e+04
#     Improvement from line search | f(prox_ls): 8.19236e+03
# [163]: fk = 8.19e+03 | error = 2.24e+02 | deltak = 1.96e-02 | tk = 7.40e+02
#     f(xk): 8.19236e+03 | f(prox): 1.62281e+04
#     Improvement from line search | f(prox_ls): 8.19125e+03
# [164]: fk = 8.19e+03 | error = 2.24e+02 | deltak = 1.94e-02 | tk = 7.33e+02
#     f(xk): 8.19125e+03 | f(prox): 1.62443e+04
#     Improvement from line search | f(prox_ls): 8.18620e+03
# [165]: fk = 8.19e+03 | error = 2.24e+02 | deltak = 1.92e-02 | tk = 7.40e+02
#     f(xk): 8.18620e+03 | f(prox): 1.57185e+04
#     Improvement from line search | f(prox_ls): 8.18661e+03
# [166]: fk = 8.19e+03 | error = 2.24e+02 | deltak = 1.90e-02 | tk = 7.47e+02
#     f(xk): 8.18661e+03 | f(prox): 1.61165e+04
#     Improvement from line search | f(prox_ls): 8.18566e+03
# [167]: fk = 8.19e+03 | error = 2.24e+02 | deltak = 1.89e-02 | tk = 7.55e+02
#     f(xk): 8.18566e+03 | f(prox): 1.62436e+04
#     Improvement from line search | f(prox_ls): 8.08248e+03
# [168]: fk = 8.08e+03 | error = 2.24e+02 | deltak = 1.87e-02 | tk = 7.62e+02
#     f(xk): 8.08248e+03 | f(prox): 1.61742e+04
#     Improvement from line search | f(prox_ls): 8.06092e+03
# [169]: fk = 8.06e+03 | error = 2.24e+02 | deltak = 1.85e-02 | tk = 7.55e+02
#     f(xk): 8.06092e+03 | f(prox): 1.47577e+04
#     Improvement from line search | f(prox_ls): 8.03745e+03
# [170]: fk = 8.04e+03 | error = 2.25e+02 | deltak = 1.83e-02 | tk = 7.62e+02
#     f(xk): 8.03745e+03 | f(prox): 1.63763e+04
#     Improvement from line search | f(prox_ls): 8.03800e+03
# [171]: fk = 8.04e+03 | error = 2.25e+02 | deltak = 1.81e-02 | tk = 7.55e+02
#     f(xk): 8.03800e+03 | f(prox): 1.62316e+04
#     Improvement from line search | f(prox_ls): 8.03943e+03
# [172]: fk = 8.04e+03 | error = 2.25e+02 | deltak = 1.79e-02 | tk = 7.47e+02
#     f(xk): 8.03943e+03 | f(prox): 1.63187e+04
#     Improvement from line search | f(prox_ls): 8.03977e+03
# [173]: fk = 8.04e+03 | error = 2.25e+02 | deltak = 1.78e-02 | tk = 7.54e+02
#     f(xk): 8.03977e+03 | f(prox): 1.63902e+04
#     Improvement from line search | f(prox_ls): 8.03712e+03
# [174]: fk = 8.04e+03 | error = 2.25e+02 | deltak = 1.76e-02 | tk = 7.62e+02
#     f(xk): 8.03712e+03 | f(prox): 1.64281e+04
#     Improvement from line search | f(prox_ls): 8.02155e+03
# [175]: fk = 8.02e+03 | error = 2.25e+02 | deltak = 1.74e-02 | tk = 7.70e+02
#     f(xk): 8.02155e+03 | f(prox): 1.58909e+04
#     Improvement from line search | f(prox_ls): 7.89954e+03
# [176]: fk = 7.90e+03 | error = 2.25e+02 | deltak = 1.72e-02 | tk = 7.77e+02
#     f(xk): 7.89954e+03 | f(prox): 1.62973e+04
#     Improvement from line search | f(prox_ls): 7.89646e+03
# [177]: fk = 7.90e+03 | error = 2.25e+02 | deltak = 1.71e-02 | tk = 7.70e+02
#     f(xk): 7.89646e+03 | f(prox): 1.61417e+04
#     Improvement from line search | f(prox_ls): 7.89561e+03
# [178]: fk = 7.90e+03 | error = 2.25e+02 | deltak = 1.69e-02 | tk = 7.77e+02
#     f(xk): 7.89561e+03 | f(prox): 1.64154e+04
#     Improvement from line search | f(prox_ls): 7.89746e+03
# [179]: fk = 7.90e+03 | error = 2.25e+02 | deltak = 1.67e-02 | tk = 7.85e+02
#     f(xk): 7.89746e+03 | f(prox): 1.50335e+04
#     Improvement from line search | f(prox_ls): 7.86998e+03
# [180]: fk = 7.87e+03 | error = 2.25e+02 | deltak = 1.65e-02 | tk = 7.93e+02
#     f(xk): 7.86998e+03 | f(prox): 1.61733e+04
#     Improvement from line search | f(prox_ls): 7.86692e+03
# [181]: fk = 7.87e+03 | error = 2.25e+02 | deltak = 1.64e-02 | tk = 7.85e+02
#     f(xk): 7.86692e+03 | f(prox): 1.63531e+04
#     Improvement from line search | f(prox_ls): 7.86841e+03
# [182]: fk = 7.87e+03 | error = 2.25e+02 | deltak = 1.62e-02 | tk = 7.93e+02
#     f(xk): 7.86841e+03 | f(prox): 1.52706e+04
#     Improvement from line search | f(prox_ls): 7.86531e+03
# [183]: fk = 7.87e+03 | error = 2.25e+02 | deltak = 1.61e-02 | tk = 8.01e+02
#     f(xk): 7.86531e+03 | f(prox): 1.55387e+04
#     Improvement from line search | f(prox_ls): 7.85911e+03
# [184]: fk = 7.86e+03 | error = 2.25e+02 | deltak = 1.59e-02 | tk = 8.09e+02
#     f(xk): 7.85911e+03 | f(prox): 1.61811e+04
#     Improvement from line search | f(prox_ls): 7.85664e+03
# [185]: fk = 7.86e+03 | error = 2.25e+02 | deltak = 1.57e-02 | tk = 8.17e+02
#     f(xk): 7.85664e+03 | f(prox): 1.58403e+04
#     Improvement from line search | f(prox_ls): 7.83873e+03
# [186]: fk = 7.84e+03 | error = 2.25e+02 | deltak = 1.56e-02 | tk = 8.25e+02
#     f(xk): 7.83873e+03 | f(prox): 1.56655e+04
#     Improvement from line search | f(prox_ls): 7.83418e+03
# [187]: fk = 7.83e+03 | error = 2.25e+02 | deltak = 1.54e-02 | tk = 8.17e+02
#     f(xk): 7.83418e+03 | f(prox): 1.60415e+04
#     Improvement from line search | f(prox_ls): 7.83486e+03
# [188]: fk = 7.83e+03 | error = 2.25e+02 | deltak = 1.53e-02 | tk = 8.25e+02
#     f(xk): 7.83486e+03 | f(prox): 1.62972e+04
#     Improvement from line search | f(prox_ls): 7.83594e+03
# [189]: fk = 7.84e+03 | error = 2.25e+02 | deltak = 1.51e-02 | tk = 8.33e+02
#     f(xk): 7.83594e+03 | f(prox): 1.56280e+04
#     Improvement from line search | f(prox_ls): 7.83327e+03
# [190]: fk = 7.83e+03 | error = 2.25e+02 | deltak = 1.50e-02 | tk = 8.41e+02
#     f(xk): 7.83327e+03 | f(prox): 1.57215e+04
#     Improvement from line search | f(prox_ls): 7.83355e+03
# [191]: fk = 7.83e+03 | error = 2.25e+02 | deltak = 1.48e-02 | tk = 8.50e+02
#     f(xk): 7.83355e+03 | f(prox): 1.60778e+04
#     Improvement from line search | f(prox_ls): 7.83052e+03
# [192]: fk = 7.83e+03 | error = 2.25e+02 | deltak = 1.47e-02 | tk = 8.58e+02
#     f(xk): 7.83052e+03 | f(prox): 1.53550e+04
#     Improvement from line search | f(prox_ls): 7.81579e+03
# [193]: fk = 7.82e+03 | error = 2.25e+02 | deltak = 1.45e-02 | tk = 8.67e+02
#     f(xk): 7.81579e+03 | f(prox): 1.60625e+04
#     Improvement from line search | f(prox_ls): 7.80399e+03
# [194]: fk = 7.80e+03 | error = 2.25e+02 | deltak = 1.44e-02 | tk = 8.76e+02
#     f(xk): 7.80399e+03 | f(prox): 1.54820e+04
#     Improvement from line search | f(prox_ls): 7.78139e+03
# [195]: fk = 7.78e+03 | error = 2.25e+02 | deltak = 1.42e-02 | tk = 8.84e+02
#     f(xk): 7.78139e+03 | f(prox): 1.64505e+04
#     Improvement from line search | f(prox_ls): 7.77634e+03
# [196]: fk = 7.78e+03 | error = 2.25e+02 | deltak = 1.41e-02 | tk = 8.76e+02
#     f(xk): 7.77634e+03 | f(prox): 1.61117e+04
#     Improvement from line search | f(prox_ls): 7.75383e+03
# [197]: fk = 7.75e+03 | error = 2.25e+02 | deltak = 1.39e-02 | tk = 8.84e+02
#     f(xk): 7.75383e+03 | f(prox): 1.58417e+04
#     Improvement from line search | f(prox_ls): 7.74665e+03
# [198]: fk = 7.75e+03 | error = 2.25e+02 | deltak = 1.38e-02 | tk = 8.93e+02
#     f(xk): 7.74665e+03 | f(prox): 1.51030e+04
#     Improvement from line search | f(prox_ls): 7.74769e+03
# [199]: fk = 7.75e+03 | error = 2.25e+02 | deltak = 1.37e-02 | tk = 8.84e+02
#     f(xk): 7.74769e+03 | f(prox): 1.60469e+04
#     Improvement from line search | f(prox_ls): 7.72209e+03
# [200]: fk = 7.72e+03 | error = 2.25e+02 | deltak = 1.35e-02 | tk = 8.93e+02
#     f(xk): 7.72209e+03 | f(prox): 1.60919e+04
#     Improvement from line search | f(prox_ls): 7.71748e+03
# [201]: fk = 7.72e+03 | error = 2.25e+02 | deltak = 1.34e-02 | tk = 8.84e+02
#     f(xk): 7.71748e+03 | f(prox): 1.62654e+04
#     Improvement from line search | f(prox_ls): 7.71555e+03
# [202]: fk = 7.72e+03 | error = 2.25e+02 | deltak = 1.33e-02 | tk = 8.93e+02
#     f(xk): 7.71555e+03 | f(prox): 1.59983e+04
#     Improvement from line search | f(prox_ls): 7.71385e+03
# [203]: fk = 7.71e+03 | error = 2.25e+02 | deltak = 1.31e-02 | tk = 9.02e+02
#     f(xk): 7.71385e+03 | f(prox): 1.56742e+04
#     Improvement from line search | f(prox_ls): 7.71175e+03
# [204]: fk = 7.71e+03 | error = 2.25e+02 | deltak = 1.30e-02 | tk = 9.11e+02
#     f(xk): 7.71175e+03 | f(prox): 1.51740e+04
#     Improvement from line search | f(prox_ls): 7.71123e+03
# [205]: fk = 7.71e+03 | error = 2.25e+02 | deltak = 1.29e-02 | tk = 9.20e+02
#     f(xk): 7.71123e+03 | f(prox): 1.60602e+04
#     Improvement from line search | f(prox_ls): 7.70634e+03
# [206]: fk = 7.71e+03 | error = 2.25e+02 | deltak = 1.27e-02 | tk = 9.29e+02
#     f(xk): 7.70634e+03 | f(prox): 1.62158e+04
#     Improvement from line search | f(prox_ls): 7.68203e+03
# [207]: fk = 7.68e+03 | error = 2.25e+02 | deltak = 1.26e-02 | tk = 9.39e+02
#     f(xk): 7.68203e+03 | f(prox): 1.58866e+04
#     Improvement from line search | f(prox_ls): 7.66992e+03
# [208]: fk = 7.67e+03 | error = 2.25e+02 | deltak = 1.25e-02 | tk = 9.48e+02
#     f(xk): 7.66992e+03 | f(prox): 1.60687e+04
#     Improvement from line search | f(prox_ls): 7.60200e+03
# [209]: fk = 7.60e+03 | error = 2.25e+02 | deltak = 1.24e-02 | tk = 9.57e+02
#     f(xk): 7.60200e+03 | f(prox): 1.60137e+04
#     Improvement from line search | f(prox_ls): 7.59973e+03
# [210]: fk = 7.60e+03 | error = 2.25e+02 | deltak = 1.22e-02 | tk = 9.48e+02
#     f(xk): 7.59973e+03 | f(prox): 1.58118e+04
#     Improvement from line search | f(prox_ls): 7.58693e+03
# [211]: fk = 7.59e+03 | error = 2.25e+02 | deltak = 1.21e-02 | tk = 9.57e+02
#     f(xk): 7.58693e+03 | f(prox): 1.64703e+04
#     Improvement from line search | f(prox_ls): 7.54970e+03
# [212]: fk = 7.55e+03 | error = 2.25e+02 | deltak = 1.20e-02 | tk = 9.67e+02
#     f(xk): 7.54970e+03 | f(prox): 1.55946e+04
#     Improvement from line search | f(prox_ls): 7.54934e+03
# [213]: fk = 7.55e+03 | error = 2.25e+02 | deltak = 1.19e-02 | tk = 9.57e+02
#     f(xk): 7.54934e+03 | f(prox): 1.59904e+04
#     Improvement from line search | f(prox_ls): 7.54989e+03
# [214]: fk = 7.55e+03 | error = 2.25e+02 | deltak = 1.18e-02 | tk = 9.67e+02
#     f(xk): 7.54989e+03 | f(prox): 1.56816e+04
#     Improvement from line search | f(prox_ls): 7.51164e+03
# [215]: fk = 7.51e+03 | error = 2.25e+02 | deltak = 1.16e-02 | tk = 9.76e+02
#     f(xk): 7.51164e+03 | f(prox): 1.56982e+04
#     Improvement from line search | f(prox_ls): 7.46298e+03
# [216]: fk = 7.46e+03 | error = 2.25e+02 | deltak = 1.15e-02 | tk = 9.86e+02
#     f(xk): 7.46298e+03 | f(prox): 1.59589e+04
#     Improvement from line search | f(prox_ls): 7.41401e+03
# [217]: fk = 7.41e+03 | error = 2.25e+02 | deltak = 1.14e-02 | tk = 9.96e+02
#     f(xk): 7.41401e+03 | f(prox): 1.62453e+04
#     Improvement from line search | f(prox_ls): 7.41035e+03
# [218]: fk = 7.41e+03 | error = 2.25e+02 | deltak = 1.13e-02 | tk = 9.86e+02
#     f(xk): 7.41035e+03 | f(prox): 1.61110e+04
#     Improvement from line search | f(prox_ls): 7.41099e+03
# [219]: fk = 7.41e+03 | error = 2.25e+02 | deltak = 1.12e-02 | tk = 9.96e+02
#     f(xk): 7.41099e+03 | f(prox): 1.60097e+04
#     Improvement from line search | f(prox_ls): 7.40881e+03
# [220]: fk = 7.41e+03 | error = 2.25e+02 | deltak = 1.11e-02 | tk = 1.01e+03
#     f(xk): 7.40881e+03 | f(prox): 1.61070e+04
#     Improvement from line search | f(prox_ls): 7.38176e+03
# [221]: fk = 7.38e+03 | error = 2.25e+02 | deltak = 1.10e-02 | tk = 1.02e+03
#     f(xk): 7.38176e+03 | f(prox): 1.60784e+04
#     Improvement from line search | f(prox_ls): 7.33482e+03
# [222]: fk = 7.33e+03 | error = 2.25e+02 | deltak = 1.08e-02 | tk = 1.03e+03
#     f(xk): 7.33482e+03 | f(prox): 1.53923e+04
#     Improvement from line search | f(prox_ls): 7.33004e+03
# [223]: fk = 7.33e+03 | error = 2.25e+02 | deltak = 1.07e-02 | tk = 1.02e+03
#     f(xk): 7.33004e+03 | f(prox): 1.61428e+04
#     Improvement from line search | f(prox_ls): 7.33143e+03
# [224]: fk = 7.33e+03 | error = 2.25e+02 | deltak = 1.06e-02 | tk = 1.03e+03
#     f(xk): 7.33143e+03 | f(prox): 1.56262e+04
#     Improvement from line search | f(prox_ls): 7.32444e+03
# [225]: fk = 7.32e+03 | error = 2.25e+02 | deltak = 1.05e-02 | tk = 1.04e+03
#     f(xk): 7.32444e+03 | f(prox): 1.54988e+04
#     Improvement from line search | f(prox_ls): 7.31743e+03
# [226]: fk = 7.32e+03 | error = 2.25e+02 | deltak = 1.04e-02 | tk = 1.05e+03
#     f(xk): 7.31743e+03 | f(prox): 1.62371e+04
#     Improvement from line search | f(prox_ls): 7.31388e+03
# [227]: fk = 7.31e+03 | error = 2.25e+02 | deltak = 1.03e-02 | tk = 1.04e+03
#     f(xk): 7.31388e+03 | f(prox): 1.62329e+04
#     Improvement from line search | f(prox_ls): 7.30364e+03
# [228]: fk = 7.30e+03 | error = 2.25e+02 | deltak = 1.02e-02 | tk = 1.05e+03
#     f(xk): 7.30364e+03 | f(prox): 1.60131e+04
#     Improvement from line search | f(prox_ls): 7.30348e+03
# [229]: fk = 7.30e+03 | error = 2.25e+02 | deltak = 1.01e-02 | tk = 1.04e+03
#     f(xk): 7.30348e+03 | f(prox): 1.56428e+04
#     Improvement from line search | f(prox_ls): 7.30313e+03
# [230]: fk = 7.30e+03 | error = 2.25e+02 | deltak = 1.00e-02 | tk = 1.05e+03
#     f(xk): 7.30313e+03 | f(prox): 1.58369e+04
#     Improvement from line search | f(prox_ls): 7.30389e+03
# [231]: fk = 7.30e+03 | error = 2.25e+02 | deltak = 9.91e-03 | tk = 1.06e+03
#     f(xk): 7.30389e+03 | f(prox): 1.49273e+04
#     Improvement from line search | f(prox_ls): 7.29968e+03
# [232]: fk = 7.30e+03 | error = 2.25e+02 | deltak = 9.81e-03 | tk = 1.07e+03
#     f(xk): 7.29968e+03 | f(prox): 1.55729e+04
#     Improvement from line search | f(prox_ls): 7.22856e+03
# [233]: fk = 7.23e+03 | error = 2.25e+02 | deltak = 9.71e-03 | tk = 1.08e+03
#     f(xk): 7.22856e+03 | f(prox): 1.58317e+04
#     Improvement from line search | f(prox_ls): 7.22196e+03
# [234]: fk = 7.22e+03 | error = 2.25e+02 | deltak = 9.62e-03 | tk = 1.07e+03
#     f(xk): 7.22196e+03 | f(prox): 1.54428e+04
#     Improvement from line search | f(prox_ls): 7.22254e+03
# [235]: fk = 7.22e+03 | error = 2.25e+02 | deltak = 9.52e-03 | tk = 1.06e+03
#     f(xk): 7.22254e+03 | f(prox): 1.56735e+04
#     Improvement from line search | f(prox_ls): 7.17290e+03
# [236]: fk = 7.17e+03 | error = 2.25e+02 | deltak = 9.42e-03 | tk = 1.07e+03
#     f(xk): 7.17290e+03 | f(prox): 1.57372e+04
#     Improvement from line search | f(prox_ls): 7.14843e+03
# [237]: fk = 7.15e+03 | error = 2.25e+02 | deltak = 9.33e-03 | tk = 1.08e+03
#     f(xk): 7.14843e+03 | f(prox): 1.51669e+04
#     Improvement from line search | f(prox_ls): 7.14773e+03
# [238]: fk = 7.15e+03 | error = 2.25e+02 | deltak = 9.24e-03 | tk = 1.07e+03
#     f(xk): 7.14773e+03 | f(prox): 1.56530e+04
#     Improvement from line search | f(prox_ls): 7.14390e+03
# [239]: fk = 7.14e+03 | error = 2.25e+02 | deltak = 9.14e-03 | tk = 1.08e+03
#     f(xk): 7.14390e+03 | f(prox): 1.57414e+04
#     Improvement from line search | f(prox_ls): 7.14193e+03
# [240]: fk = 7.14e+03 | error = 2.25e+02 | deltak = 9.05e-03 | tk = 1.09e+03
#     f(xk): 7.14193e+03 | f(prox): 1.58259e+04
#     Improvement from line search | f(prox_ls): 7.12632e+03
# [241]: fk = 7.13e+03 | error = 2.25e+02 | deltak = 8.96e-03 | tk = 1.10e+03
#     f(xk): 7.12632e+03 | f(prox): 1.53175e+04
#     Improvement from line search | f(prox_ls): 7.12686e+03
# [242]: fk = 7.13e+03 | error = 2.25e+02 | deltak = 8.87e-03 | tk = 1.09e+03
#     f(xk): 7.12686e+03 | f(prox): 1.48197e+04
#     Improvement from line search | f(prox_ls): 7.12235e+03
# [243]: fk = 7.12e+03 | error = 2.25e+02 | deltak = 8.78e-03 | tk = 1.10e+03
#     f(xk): 7.12235e+03 | f(prox): 1.63233e+04
#     Improvement from line search | f(prox_ls): 7.10670e+03
# [244]: fk = 7.11e+03 | error = 2.25e+02 | deltak = 8.70e-03 | tk = 1.11e+03
#     f(xk): 7.10670e+03 | f(prox): 1.63134e+04
#     Improvement from line search | f(prox_ls): 7.09424e+03
# [245]: fk = 7.09e+03 | error = 2.25e+02 | deltak = 8.61e-03 | tk = 1.12e+03
#     f(xk): 7.09424e+03 | f(prox): 1.60556e+04
#     Improvement from line search | f(prox_ls): 7.09313e+03
# [246]: fk = 7.09e+03 | error = 2.25e+02 | deltak = 8.52e-03 | tk = 1.11e+03
#     f(xk): 7.09313e+03 | f(prox): 1.60196e+04
#     Improvement from line search | f(prox_ls): 7.09385e+03
# [247]: fk = 7.09e+03 | error = 2.25e+02 | deltak = 8.44e-03 | tk = 1.12e+03
#     f(xk): 7.09385e+03 | f(prox): 1.57742e+04
#     Improvement from line search | f(prox_ls): 7.09089e+03
# [248]: fk = 7.09e+03 | error = 2.25e+02 | deltak = 8.35e-03 | tk = 1.13e+03
#     f(xk): 7.09089e+03 | f(prox): 1.56071e+04
#     Improvement from line search | f(prox_ls): 7.08836e+03
# [249]: fk = 7.09e+03 | error = 2.25e+02 | deltak = 8.27e-03 | tk = 1.14e+03
#     f(xk): 7.08836e+03 | f(prox): 1.58909e+04
#     Improvement from line search | f(prox_ls): 7.07807e+03
# [250]: fk = 7.08e+03 | error = 2.25e+02 | deltak = 8.19e-03 | tk = 1.16e+03
#     f(xk): 7.07807e+03 | f(prox): 1.48729e+04
#     Improvement from line search | f(prox_ls): 7.04308e+03
# [251]: fk = 7.04e+03 | error = 2.25e+02 | deltak = 8.11e-03 | tk = 1.17e+03
#     f(xk): 7.04308e+03 | f(prox): 1.61807e+04
#     Improvement from line search | f(prox_ls): 7.03157e+03
# [252]: fk = 7.03e+03 | error = 2.25e+02 | deltak = 8.02e-03 | tk = 1.16e+03
#     f(xk): 7.03157e+03 | f(prox): 1.61530e+04
#     Improvement from line search | f(prox_ls): 7.01123e+03
# [253]: fk = 7.01e+03 | error = 2.25e+02 | deltak = 7.94e-03 | tk = 1.17e+03
#     f(xk): 7.01123e+03 | f(prox): 1.60597e+04
#     Improvement from line search | f(prox_ls): 6.98855e+03
# [254]: fk = 6.99e+03 | error = 2.25e+02 | deltak = 7.87e-03 | tk = 1.18e+03
#     f(xk): 6.98855e+03 | f(prox): 1.63252e+04
#     Improvement from line search | f(prox_ls): 6.98917e+03
# [255]: fk = 6.99e+03 | error = 2.25e+02 | deltak = 7.79e-03 | tk = 1.17e+03
#     f(xk): 6.98917e+03 | f(prox): 1.61346e+04
#     Improvement from line search | f(prox_ls): 6.98447e+03
# [256]: fk = 6.98e+03 | error = 2.25e+02 | deltak = 7.71e-03 | tk = 1.18e+03
#     f(xk): 6.98447e+03 | f(prox): 1.53686e+04
#     Improvement from line search | f(prox_ls): 6.98487e+03
# [257]: fk = 6.98e+03 | error = 2.25e+02 | deltak = 7.63e-03 | tk = 1.19e+03
#     f(xk): 6.98487e+03 | f(prox): 1.60773e+04
#     Improvement from line search | f(prox_ls): 6.98592e+03
# [258]: fk = 6.99e+03 | error = 2.25e+02 | deltak = 7.56e-03 | tk = 1.20e+03
#     f(xk): 6.98592e+03 | f(prox): 1.54699e+04
#     Improvement from line search | f(prox_ls): 6.97380e+03
# [259]: fk = 6.97e+03 | error = 2.25e+02 | deltak = 7.48e-03 | tk = 1.21e+03
#     f(xk): 6.97380e+03 | f(prox): 1.58407e+04
#     Improvement from line search | f(prox_ls): 6.96081e+03
# [260]: fk = 6.96e+03 | error = 2.25e+02 | deltak = 7.40e-03 | tk = 1.23e+03
#     f(xk): 6.96081e+03 | f(prox): 1.58694e+04
#     Improvement from line search | f(prox_ls): 6.94570e+03
# [261]: fk = 6.95e+03 | error = 2.25e+02 | deltak = 7.33e-03 | tk = 1.24e+03
#     f(xk): 6.94570e+03 | f(prox): 1.59542e+04
#     Improvement from line search | f(prox_ls): 6.94445e+03
# [262]: fk = 6.94e+03 | error = 2.25e+02 | deltak = 7.26e-03 | tk = 1.23e+03
#     f(xk): 6.94445e+03 | f(prox): 1.60019e+04
#     Improvement from line search | f(prox_ls): 6.94101e+03
# [263]: fk = 6.94e+03 | error = 2.25e+02 | deltak = 7.18e-03 | tk = 1.24e+03
#     f(xk): 6.94101e+03 | f(prox): 1.59267e+04
#     Improvement from line search | f(prox_ls): 6.93859e+03
# [264]: fk = 6.94e+03 | error = 2.25e+02 | deltak = 7.11e-03 | tk = 1.25e+03
#     f(xk): 6.93859e+03 | f(prox): 1.54380e+04
# ...
# [405]: fk = 5.53e+03 | error = 2.24e+02 | deltak = 1.72e-03 | tk = 1.99e+03
#     f(xk): 5.53456e+03 | f(prox): 1.56268e+04
#     Improvement from line search | f(prox_ls): 5.51487e+03
# [406]: fk = 5.51e+03 | error = 2.24e+02 | deltak = 1.71e-03 | tk = 2.01e+03
#     f(xk): 5.51487e+03 | f(prox): 1.54075e+04
#     Improvement from line search | f(prox_ls): 5.51498e+03
# [407]: fk = 5.51e+03 | error = 2.24e+02 | deltak = 1.69e-03 | tk = 1.99e+03
#     f(xk): 5.51498e+03 | f(prox): 1.57281e+04
#     Improvement from line search | f(prox_ls): 5.51472e+03
# [408]: fk = 5.51e+03 | error = 2.24e+02 | deltak = 1.67e-03 | tk = 2.01e+03
#     f(xk): 5.51472e+03 | f(prox): 1.55460e+04
#     Improvement from line search | f(prox_ls): 5.51359e+03
# [409]: fk = 5.51e+03 | error = 2.24e+02 | deltak = 1.66e-03 | tk = 2.03e+03
#     f(xk): 5.51359e+03 | f(prox): 1.55843e+04
#     Improvement from line search | f(prox_ls): 5.47214e+03
# [410]: fk = 5.47e+03 | error = 2.24e+02 | deltak = 1.64e-03 | tk = 2.05e+03
#     f(xk): 5.47214e+03 | f(prox): 1.49475e+04
#     Improvement from line search | f(prox_ls): 5.47143e+03
# [411]: fk = 5.47e+03 | error = 2.24e+02 | deltak = 1.62e-03 | tk = 2.03e+03
#     f(xk): 5.47143e+03 | f(prox): 1.52250e+04
#     Improvement from line search | f(prox_ls): 5.47065e+03
# [412]: fk = 5.47e+03 | error = 2.24e+02 | deltak = 1.61e-03 | tk = 2.05e+03
#     f(xk): 5.47065e+03 | f(prox): 1.51994e+04
#     Improvement from line search | f(prox_ls): 5.45110e+03
# [413]: fk = 5.45e+03 | error = 2.24e+02 | deltak = 1.59e-03 | tk = 2.07e+03
#     f(xk): 5.45110e+03 | f(prox): 1.55026e+04
#     Improvement from line search | f(prox_ls): 5.45050e+03
# [414]: fk = 5.45e+03 | error = 2.24e+02 | deltak = 1.58e-03 | tk = 2.05e+03
#     f(xk): 5.45050e+03 | f(prox): 1.49511e+04
#     Improvement from line search | f(prox_ls): 5.44560e+03
# [415]: fk = 5.45e+03 | error = 2.24e+02 | deltak = 1.56e-03 | tk = 2.07e+03
#     f(xk): 5.44560e+03 | f(prox): 1.54982e+04
#     Improvement from line search | f(prox_ls): 5.42937e+03
# [416]: fk = 5.43e+03 | error = 2.24e+02 | deltak = 1.54e-03 | tk = 2.09e+03
#     f(xk): 5.42937e+03 | f(prox): 1.54539e+04
#     Improvement from line search | f(prox_ls): 5.38062e+03
# [417]: fk = 5.38e+03 | error = 2.24e+02 | deltak = 1.53e-03 | tk = 2.11e+03
#     f(xk): 5.38062e+03 | f(prox): 1.57363e+04
#     Improvement from line search | f(prox_ls): 5.30210e+03
# [418]: fk = 5.30e+03 | error = 2.24e+02 | deltak = 1.51e-03 | tk = 2.13e+03
#     f(xk): 5.30210e+03 | f(prox): 1.54866e+04
#     Improvement from line search | f(prox_ls): 5.29976e+03
# [419]: fk = 5.30e+03 | error = 2.24e+02 | deltak = 1.50e-03 | tk = 2.11e+03
#     f(xk): 5.29976e+03 | f(prox): 1.53618e+04
#     Improvement from line search | f(prox_ls): 5.27290e+03
# [420]: fk = 5.27e+03 | error = 2.24e+02 | deltak = 1.48e-03 | tk = 2.13e+03
#     f(xk): 5.27290e+03 | f(prox): 1.47733e+04
#     Improvement from line search | f(prox_ls): 5.27243e+03
# [421]: fk = 5.27e+03 | error = 2.24e+02 | deltak = 1.47e-03 | tk = 2.11e+03
#     f(xk): 5.27243e+03 | f(prox): 1.54625e+04
#     Improvement from line search | f(prox_ls): 5.27275e+03
# [422]: fk = 5.27e+03 | error = 2.24e+02 | deltak = 1.45e-03 | tk = 2.13e+03
#     f(xk): 5.27275e+03 | f(prox): 1.50540e+04
#     Improvement from line search | f(prox_ls): 5.25664e+03
# [423]: fk = 5.26e+03 | error = 2.24e+02 | deltak = 1.44e-03 | tk = 2.15e+03
#     f(xk): 5.25664e+03 | f(prox): 1.47673e+04
#     Improvement from line search | f(prox_ls): 5.25078e+03
# [424]: fk = 5.25e+03 | error = 2.24e+02 | deltak = 1.42e-03 | tk = 2.13e+03
#     f(xk): 5.25078e+03 | f(prox): 1.52520e+04
#     Improvement from line search | f(prox_ls): 5.23827e+03
# [425]: fk = 5.24e+03 | error = 2.24e+02 | deltak = 1.41e-03 | tk = 2.15e+03
#     f(xk): 5.23827e+03 | f(prox): 1.50946e+04
#     Improvement from line search | f(prox_ls): 5.23773e+03
# [426]: fk = 5.24e+03 | error = 2.24e+02 | deltak = 1.40e-03 | tk = 2.13e+03
#     f(xk): 5.23773e+03 | f(prox): 1.56771e+04
#     Improvement from line search | f(prox_ls): 5.23364e+03
# [427]: fk = 5.23e+03 | error = 2.24e+02 | deltak = 1.38e-03 | tk = 2.15e+03
#     f(xk): 5.23364e+03 | f(prox): 1.52515e+04
#     Improvement from line search | f(prox_ls): 5.23230e+03
# [428]: fk = 5.23e+03 | error = 2.24e+02 | deltak = 1.37e-03 | tk = 2.13e+03
#     f(xk): 5.23230e+03 | f(prox): 1.55811e+04
#     Improvement from line search | f(prox_ls): 5.22298e+03
# [429]: fk = 5.22e+03 | error = 2.24e+02 | deltak = 1.35e-03 | tk = 2.15e+03
#     f(xk): 5.22298e+03 | f(prox): 1.49065e+04
#     Improvement from line search | f(prox_ls): 5.21531e+03
# [430]: fk = 5.22e+03 | error = 2.24e+02 | deltak = 1.34e-03 | tk = 2.17e+03
#     f(xk): 5.21531e+03 | f(prox): 1.54320e+04
#     Improvement from line search | f(prox_ls): 5.20856e+03
# [431]: fk = 5.21e+03 | error = 2.24e+02 | deltak = 1.33e-03 | tk = 2.15e+03
#     f(xk): 5.20856e+03 | f(prox): 1.55132e+04
#     Improvement from line search | f(prox_ls): 5.20691e+03
# [432]: fk = 5.21e+03 | error = 2.24e+02 | deltak = 1.31e-03 | tk = 2.13e+03
#     f(xk): 5.20691e+03 | f(prox): 1.52347e+04
#     Improvement from line search | f(prox_ls): 5.20308e+03
# [433]: fk = 5.20e+03 | error = 2.24e+02 | deltak = 1.30e-03 | tk = 2.15e+03
#     f(xk): 5.20308e+03 | f(prox): 1.54696e+04
#     Improvement from line search | f(prox_ls): 5.20323e+03
# [434]: fk = 5.20e+03 | error = 2.24e+02 | deltak = 1.29e-03 | tk = 2.13e+03
#     f(xk): 5.20323e+03 | f(prox): 1.52940e+04
#     Improvement from line search | f(prox_ls): 5.20260e+03
# [435]: fk = 5.20e+03 | error = 2.24e+02 | deltak = 1.28e-03 | tk = 2.15e+03
#     f(xk): 5.20260e+03 | f(prox): 1.51387e+04
#     Improvement from line search | f(prox_ls): 5.19976e+03
# [436]: fk = 5.20e+03 | error = 2.24e+02 | deltak = 1.26e-03 | tk = 2.17e+03
#     f(xk): 5.19976e+03 | f(prox): 1.46201e+04
#     Improvement from line search | f(prox_ls): 5.19976e+03
# [437]: fk = 5.20e+03 | error = 2.24e+02 | deltak = 1.25e-03 | tk = 2.15e+03
#     f(xk): 5.19976e+03 | f(prox): 1.47152e+04
#     Improvement from line search | f(prox_ls): 5.19757e+03
# [438]: fk = 5.20e+03 | error = 2.24e+02 | deltak = 1.24e-03 | tk = 2.17e+03
#     f(xk): 5.19757e+03 | f(prox): 1.54419e+04
#     Improvement from line search | f(prox_ls): 5.19545e+03
# [439]: fk = 5.20e+03 | error = 2.24e+02 | deltak = 1.23e-03 | tk = 2.19e+03
#     f(xk): 5.19545e+03 | f(prox): 1.50589e+04
#     Improvement from line search | f(prox_ls): 5.19365e+03
# [440]: fk = 5.19e+03 | error = 2.24e+02 | deltak = 1.21e-03 | tk = 2.21e+03
#     f(xk): 5.19365e+03 | f(prox): 1.54353e+04
#     Improvement from line search | f(prox_ls): 5.17461e+03
# [441]: fk = 5.17e+03 | error = 2.24e+02 | deltak = 1.20e-03 | tk = 2.24e+03
#     f(xk): 5.17461e+03 | f(prox): 1.46044e+04
#     Improvement from line search | f(prox_ls): 5.17406e+03
# [442]: fk = 5.17e+03 | error = 2.24e+02 | deltak = 1.19e-03 | tk = 2.21e+03
#     f(xk): 5.17406e+03 | f(prox): 1.58500e+04
#     Improvement from line search | f(prox_ls): 5.17300e+03
# [443]: fk = 5.17e+03 | error = 2.24e+02 | deltak = 1.18e-03 | tk = 2.24e+03
#     f(xk): 5.17300e+03 | f(prox): 1.54776e+04
#     Improvement from line search | f(prox_ls): 5.17309e+03
# [444]: fk = 5.17e+03 | error = 2.24e+02 | deltak = 1.17e-03 | tk = 2.26e+03
#     f(xk): 5.17309e+03 | f(prox): 1.47917e+04
#     Improvement from line search | f(prox_ls): 5.17240e+03
# [445]: fk = 5.17e+03 | error = 2.24e+02 | deltak = 1.15e-03 | tk = 2.28e+03
#     f(xk): 5.17240e+03 | f(prox): 1.51576e+04
#     Improvement from line search | f(prox_ls): 5.14890e+03
# [446]: fk = 5.15e+03 | error = 2.24e+02 | deltak = 1.14e-03 | tk = 2.30e+03
#     f(xk): 5.14890e+03 | f(prox): 1.49283e+04
#     Improvement from line search | f(prox_ls): 5.14815e+03
# [447]: fk = 5.15e+03 | error = 2.24e+02 | deltak = 1.13e-03 | tk = 2.28e+03
#     f(xk): 5.14815e+03 | f(prox): 1.40291e+04
#     Improvement from line search | f(prox_ls): 5.13674e+03
# [448]: fk = 5.14e+03 | error = 2.24e+02 | deltak = 1.12e-03 | tk = 2.30e+03
#     f(xk): 5.13674e+03 | f(prox): 1.48055e+04
#     Improvement from line search | f(prox_ls): 5.13699e+03
# [449]: fk = 5.14e+03 | error = 2.24e+02 | deltak = 1.11e-03 | tk = 2.28e+03
#     f(xk): 5.13699e+03 | f(prox): 1.49605e+04
#     Improvement from line search | f(prox_ls): 5.12405e+03
# [450]: fk = 5.12e+03 | error = 2.25e+02 | deltak = 1.10e-03 | tk = 2.30e+03
#     f(xk): 5.12405e+03 | f(prox): 1.47200e+04
#     Improvement from line search | f(prox_ls): 5.12227e+03
# [451]: fk = 5.12e+03 | error = 2.25e+02 | deltak = 1.09e-03 | tk = 2.28e+03
#     f(xk): 5.12227e+03 | f(prox): 1.49106e+04
#     Improvement from line search | f(prox_ls): 5.10193e+03
# [452]: fk = 5.10e+03 | error = 2.24e+02 | deltak = 1.08e-03 | tk = 2.30e+03
#     f(xk): 5.10193e+03 | f(prox): 1.53196e+04
#     Improvement from line search | f(prox_ls): 5.10179e+03
# [453]: fk = 5.10e+03 | error = 2.24e+02 | deltak = 1.06e-03 | tk = 2.28e+03
#     f(xk): 5.10179e+03 | f(prox): 1.48963e+04
#     Improvement from line search | f(prox_ls): 5.08595e+03
# [454]: fk = 5.09e+03 | error = 2.24e+02 | deltak = 1.05e-03 | tk = 2.30e+03
#     f(xk): 5.08595e+03 | f(prox): 1.46745e+04
#     Improvement from line search | f(prox_ls): 5.07766e+03
# [455]: fk = 5.08e+03 | error = 2.24e+02 | deltak = 1.04e-03 | tk = 2.28e+03
#     f(xk): 5.07766e+03 | f(prox): 1.53634e+04
#     Improvement from line search | f(prox_ls): 5.07707e+03
# [456]: fk = 5.08e+03 | error = 2.24e+02 | deltak = 1.03e-03 | tk = 2.26e+03
#     f(xk): 5.07707e+03 | f(prox): 1.47286e+04
#     Improvement from line search | f(prox_ls): 5.07689e+03
# [457]: fk = 5.08e+03 | error = 2.24e+02 | deltak = 1.02e-03 | tk = 2.28e+03
#     f(xk): 5.07689e+03 | f(prox): 1.51793e+04
#     Improvement from line search | f(prox_ls): 5.07549e+03
# [458]: fk = 5.08e+03 | error = 2.24e+02 | deltak = 1.01e-03 | tk = 2.30e+03
#     f(xk): 5.07549e+03 | f(prox): 1.49241e+04
#     Improvement from line search | f(prox_ls): 5.07534e+03
# [459]: fk = 5.08e+03 | error = 2.24e+02 | deltak = 1.00e-03 | tk = 2.28e+03
#     f(xk): 5.07534e+03 | f(prox): 1.47030e+04
#     Improvement from line search | f(prox_ls): 5.06490e+03
# [460]: fk = 5.06e+03 | error = 2.24e+02 | deltak = 9.92e-04 | tk = 2.30e+03
#     f(xk): 5.06490e+03 | f(prox): 1.48832e+04
#     Improvement from line search | f(prox_ls): 5.05735e+03
# [461]: fk = 5.06e+03 | error = 2.24e+02 | deltak = 9.82e-04 | tk = 2.28e+03
#     f(xk): 5.05735e+03 | f(prox): 1.54091e+04
#     Improvement from line search | f(prox_ls): 5.04759e+03
# [462]: fk = 5.05e+03 | error = 2.24e+02 | deltak = 9.72e-04 | tk = 2.30e+03
#     f(xk): 5.04759e+03 | f(prox): 1.41744e+04
#     Improvement from line search | f(prox_ls): 5.04667e+03
# [463]: fk = 5.05e+03 | error = 2.24e+02 | deltak = 9.63e-04 | tk = 2.28e+03
#     f(xk): 5.04667e+03 | f(prox): 1.44349e+04
#     Improvement from line search | f(prox_ls): 5.04632e+03
# [464]: fk = 5.05e+03 | error = 2.24e+02 | deltak = 9.53e-04 | tk = 2.30e+03
#     f(xk): 5.04632e+03 | f(prox): 1.49748e+04
#     Improvement from line search | f(prox_ls): 5.02149e+03
# [465]: fk = 5.02e+03 | error = 2.24e+02 | deltak = 9.43e-04 | tk = 2.32e+03
#     f(xk): 5.02149e+03 | f(prox): 1.51892e+04
#     Improvement from line search | f(prox_ls): 4.99890e+03
# [466]: fk = 5.00e+03 | error = 2.24e+02 | deltak = 9.34e-04 | tk = 2.30e+03
#     f(xk): 4.99890e+03 | f(prox): 1.48929e+04
#     Improvement from line search | f(prox_ls): 4.97263e+03
# [467]: fk = 4.97e+03 | error = 2.24e+02 | deltak = 9.25e-04 | tk = 2.32e+03
#     f(xk): 4.97263e+03 | f(prox): 1.47180e+04
#     Improvement from line search | f(prox_ls): 4.96996e+03
# [468]: fk = 4.97e+03 | error = 2.24e+02 | deltak = 9.15e-04 | tk = 2.30e+03
#     f(xk): 4.96996e+03 | f(prox): 1.43090e+04
#     Improvement from line search | f(prox_ls): 4.97012e+03
# [469]: fk = 4.97e+03 | error = 2.24e+02 | deltak = 9.06e-04 | tk = 2.28e+03
#     f(xk): 4.97012e+03 | f(prox): 1.45344e+04
#     Improvement from line search | f(prox_ls): 4.95650e+03
# [470]: fk = 4.96e+03 | error = 2.24e+02 | deltak = 8.97e-04 | tk = 2.30e+03
#     f(xk): 4.95650e+03 | f(prox): 1.44549e+04
#     Improvement from line search | f(prox_ls): 4.95658e+03
# [471]: fk = 4.96e+03 | error = 2.24e+02 | deltak = 8.88e-04 | tk = 2.28e+03
#     f(xk): 4.95658e+03 | f(prox): 1.45698e+04
#     Improvement from line search | f(prox_ls): 4.95652e+03
# [472]: fk = 4.96e+03 | error = 2.24e+02 | deltak = 8.79e-04 | tk = 2.30e+03
#     f(xk): 4.95652e+03 | f(prox): 1.46347e+04
#     Improvement from line search | f(prox_ls): 4.95293e+03
# [473]: fk = 4.95e+03 | error = 2.24e+02 | deltak = 8.71e-04 | tk = 2.32e+03
#     f(xk): 4.95293e+03 | f(prox): 1.44197e+04
#     Improvement from line search | f(prox_ls): 4.95278e+03
# [474]: fk = 4.95e+03 | error = 2.24e+02 | deltak = 8.62e-04 | tk = 2.30e+03
#     f(xk): 4.95278e+03 | f(prox): 1.40874e+04
#     Improvement from line search | f(prox_ls): 4.95281e+03
# [475]: fk = 4.95e+03 | error = 2.24e+02 | deltak = 8.53e-04 | tk = 2.32e+03
#     f(xk): 4.95281e+03 | f(prox): 1.47766e+04
#     Improvement from line search | f(prox_ls): 4.93878e+03
# [476]: fk = 4.94e+03 | error = 2.24e+02 | deltak = 8.45e-04 | tk = 2.35e+03
#     f(xk): 4.93878e+03 | f(prox): 1.35094e+04
#     Improvement from line search | f(prox_ls): 4.93129e+03
# [477]: fk = 4.93e+03 | error = 2.24e+02 | deltak = 8.36e-04 | tk = 2.32e+03
#     f(xk): 4.93129e+03 | f(prox): 1.49628e+04
#     Improvement from line search | f(prox_ls): 4.92005e+03
# [478]: fk = 4.92e+03 | error = 2.24e+02 | deltak = 8.28e-04 | tk = 2.35e+03
#     f(xk): 4.92005e+03 | f(prox): 1.44796e+04
#     Improvement from line search | f(prox_ls): 4.91957e+03
# [479]: fk = 4.92e+03 | error = 2.24e+02 | deltak = 8.20e-04 | tk = 2.32e+03
#     f(xk): 4.91957e+03 | f(prox): 1.46759e+04
#     Improvement from line search | f(prox_ls): 4.88015e+03
# [480]: fk = 4.88e+03 | error = 2.24e+02 | deltak = 8.11e-04 | tk = 2.35e+03
#     f(xk): 4.88015e+03 | f(prox): 1.46151e+04
#     Improvement from line search | f(prox_ls): 4.87863e+03
# [481]: fk = 4.88e+03 | error = 2.24e+02 | deltak = 8.03e-04 | tk = 2.32e+03
#     f(xk): 4.87863e+03 | f(prox): 1.39789e+04
#     Improvement from line search | f(prox_ls): 4.86988e+03
# [482]: fk = 4.87e+03 | error = 2.24e+02 | deltak = 7.95e-04 | tk = 2.35e+03
#     f(xk): 4.86988e+03 | f(prox): 1.46902e+04
#     Improvement from line search | f(prox_ls): 4.86345e+03
# [483]: fk = 4.86e+03 | error = 2.24e+02 | deltak = 7.87e-04 | tk = 2.32e+03
#     f(xk): 4.86345e+03 | f(prox): 1.38671e+04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 15
#      11 start_time = time.time()  # Record the start time
#      14 # Execute the HJ_MAD_CD algorithm and retrieve results
# ---> 15 x_opt_gauss, xk_hist_gauss, xk_error_hist_gauss, fk_hist_gauss,delta_hist_gauss,tk_hist_gauss, successful_ls_portion = hj_md_gauss.run(x0)
#      17 elapsed_time = time.time() - start_time  # Calculate elapsed time
#      18 sum_elapsed_time += elapsed_time  # Accumulate elapsed time
#
# File ~/hj-global-opt/hj_md_ls.py:584, in HJ_MAD_LS.run(self, x0)
#     582 # Line Search
#     583 if self.line_search:
# --> 584     prox_xk_new = self.improve_prox_with_line_search(xk,prox_xk,deltak,tk)
#     585     f_prox_new = self.f(prox_xk_new.view(1, self.n_features)).item()
#     586     if f_prox_new < f_prox:
#
# File ~/hj-global-opt/hj_md_ls.py:321, in HJ_MAD_LS.improve_prox_with_line_search(self, xk, prox_xk, deltak, tk)
#     318 tau = tau_xk - self.z_line*sigma # Size (int_samples,1)
#     319 z = xk_expanded + tau.view(-1, 1) * direction_expanded
# --> 321 f_values = self.f(z)
#     323 # Apply Rescaling to Exponent
#     324 rescaled_exponent = - rescale_factor*f_values/ self.delta
#
# Cell In[8], line 209, in f(x)
#     208 def f(x):
# --> 209   return Levy(x)
#
# File ~/hj-global-opt/test_functions.py:62, in Levy(x)
#      60 w = 1 + (x-1)/4
#      61 init_term = torch.sin(np.pi*w[:,0]) ** 2
# ---> 62 fin_term  = (w[:,n_features-1] - 1)**2 * (1 + torch.sin(2*np.pi*w[:,n_features-1]))
#      64 for i in range(n_features-1):
#      65   f_val = f_val + (w[:,i]-1)**2 * ( 1 + 10*torch.sin( np.pi*w[:,i] + 1)**2 )
#
# KeyboardInterrupt:

# %% [markdown]
# ### Generate Convergence Histories and Optimization Path Plots

# %%
title_fontsize = 22
fontsize       = 18
fig1 = plt.figure()

plt.style.use('seaborn-whitegrid')
ax = plt.axes()

ax.semilogy(xk_error_hist_cauchy, color='blue', linewidth=3,label='Cauchy')
ax.semilogy(xk_error_hist_gauss, color='green', linestyle='--', linewidth=3,label='Gaussian')


ax.set_title(f'Dims={dim},Func={f_name},\n With delta dampening and adaptive time', fontsize=title_fontsize)
ax.set_xlabel("Iterations", fontsize=title_fontsize)
ax.set_ylabel("Errors", fontsize=title_fontsize)
ax.legend(fontsize=fontsize)

ax.tick_params(labelsize=fontsize, which='both', direction='in')

# save_str = 'griewank_error_hist.png'
# fig1.savefig(save_str, dpi=300 , bbox_inches="tight", pad_inches=0.0)

# %%
fig1 = plt.figure()

plt.style.use('seaborn-whitegrid')
ax = plt.axes()
#ax.semilogy(fk_hist, color='blue', linewidth=3);
#ax.semilogy(fk_hist_no_mo, color='green', linestyle='--', linewidth=3);
ax.semilogy(fk_hist_ls, color='blue', linewidth=3,label='Gaussian')
# ax.semilogy(fk_hist_ls_gauss, color='green', linestyle='--', linewidth=3,label='beta=0.5')
# ax.semilogy(fk_hist_ls, color='red', linewidth=3,label='Cauchy')
#ax.semilogy(fk_hist_ls_no_mo, color='red', linestyle='--', linewidth=3);

ax.set_xlabel("Iterations", fontsize=title_fontsize)
ax.set_ylabel("fk", fontsize=title_fontsize)
ax.legend(fontsize=fontsize)
title_str = 'Objective Function Values'
ax.set_title(title_str, fontsize=title_fontsize)
ax.tick_params(labelsize=fontsize, which='both', direction='in')

# save_str = 'griewank_func_hist.png'
# fig1.savefig(save_str, dpi=300 , bbox_inches="tight", pad_inches=0.0)

# %%
fig1 = plt.figure()

plt.style.use('seaborn-whitegrid')
ax = plt.axes()
#ax.semilogy(fk_hist, color='blue', linewidth=3);
#ax.semilogy(fk_hist_no_mo, color='green', linestyle='--', linewidth=3);
ax.semilogy(delta_hist_ls, color='blue', linewidth=3,label='gaussian')
# ax.semilogy(delta_hist_ls_gauss, color='green', linestyle='--', linewidth=3,label='beta=0.5')
# ax.semilogy(delta_hist_ls, color='red', linewidth=3,label='Cauchy')
#ax.semilogy(fk_hist_ls_no_mo, color='red', linestyle='--', linewidth=3);

ax.set_xlabel("Iterations", fontsize=title_fontsize)
ax.set_ylabel("delta", fontsize=title_fontsize)
ax.legend(fontsize=fontsize)
title_str = 'Delta Dampening'
ax.set_title(title_str, fontsize=title_fontsize)
ax.tick_params(labelsize=fontsize, which='both', direction='in')

# %% [markdown]
# ## 2D Plots

# %%
# if dim == 2:

if f_name == 'Levy':
  x0      = -15*torch.ones(dim, dtype=torch.double)
  x_true  = torch.ones(dim, dtype=torch.double)
else:
  x0      = 10*torch.ones(dim, dtype=torch.double)
  x_true  = torch.zeros(dim, dtype=torch.double)

surface_plot_resolution = 60
ax_bry = 40

x = np.linspace(-ax_bry, ax_bry, surface_plot_resolution)
y = np.linspace(-ax_bry, ax_bry, surface_plot_resolution)

X, Y = np.meshgrid(x, y)
n_features = 2

t_final = t

Z                 = np.zeros(X.shape)
Z_MAD             = np.zeros(X.shape)

for i in range(X.shape[0]):
  for j in range(X.shape[1]):
    Z[i,j] = f(torch.FloatTensor([X[i,j],Y[i,j]]).view(1,n_features))  
    

fig, ax = plt.subplots(1, 1)
im = ax.contourf(X, Y, Z, 20, cmap=plt.get_cmap('gray'))
plt.style.use('default')

title_fontsize = 22
fontsize       = 15
#coordinate_wise_xk_hist_np = np.vstack(xk_hist)


ax.plot(np.vstack(xk_hist_ls_beta)[:,0], np.vstack(xk_hist_ls_beta)[:,1], 'g-o')

#ax.plot(np.vstack(xk_hist_no_mo)[:,0], np.vstack(xk_hist_no_mo)[:,1], '-o', color='purple')

# ax.plot(np.vstack(xk_hist_ls)[:,0], np.vstack(xk_hist_ls)[:,1], 'b-o')


ax.plot(x_true[0], x_true[1], 'rx', markeredgewidth=3, markersize=12)
ax.plot(x0[0], x0[1], 'x', markeredgewidth=3, markersize=12, color='cyan')

ax.legend([ 'HJ-MD-LS', 'global min', 'initial guess'], fontsize=12, facecolor='white', markerfirst=False)

ax.set_xlim(-ax_bry,ax_bry)
cb = plt.colorbar(im)

# save_loc = 'optimization_paths.png'
# plt.savefig(save_loc,bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Interactive 2D Plot

# %%
if dim == 2:
    from mpl_toolkits.mplot3d import Axes3D
    import matplotlib.pyplot as plt
    import numpy as np

    ax_bry_3D_plot = 20
    surface_plot_resolution = 50
    x = np.linspace(-ax_bry_3D_plot, ax_bry_3D_plot, surface_plot_resolution)
    y = np.linspace(-ax_bry_3D_plot, ax_bry_3D_plot, surface_plot_resolution)

    X, Y = np.meshgrid(x, y)
    # Convert PyTorch tensors to NumPy
    # xk_hist_MAD_np = xk_hist_MAD.numpy()
    coordinate_wise_xk_hist_np = np.vstack(xk_hist_cd)

    # # Ensure z_values are scalars
    # HJ_MAD_f_values = np.array([
    #     f(torch.FloatTensor([[xk_hist_MAD_np[i, 0], xk_hist_MAD_np[i, 1]]])).item()
    #     for i in range(len(xk_hist_MAD_np))
    # ])

    HJ_MAD_CD_f_values = np.array([
        f(torch.FloatTensor([[coordinate_wise_xk_hist_np[i, 0], coordinate_wise_xk_hist_np[i, 1]]])).item()
        for i in range(len(coordinate_wise_xk_hist_np))
    ])

    # Global minimum and initial guess
    if x_true.dim() == 1:
        x_true = x_true.unsqueeze(0)
    global_min_f = f(x_true).item()

    # Initial guess point
    if x0.dim() == 1:
        x0 = x0.unsqueeze(0)
    f_initial = f(x0).item()

# %%
if dim == 2:
    import plotly.graph_objects as go

    # Create surface trace
    surface_trace = go.Surface(
        z=Z, x=X, y=Y, colorscale='Viridis', showscale=True, name='Surface'
    )

    # # Create optimization paths
    # HJ_MAD_trace = go.Scatter3d(
    #     x=xk_hist_MAD_np[:, 0],
    #     y=xk_hist_MAD_np[:, 1],
    #     z=HJ_MAD_f_values,
    #     mode='lines+markers',
    #     marker=dict(size=5, color='red'),
    #     line=dict(color='red', width=3),
    #     name='HJ-MAD'
    # )

    HJ_MAD_CD_trace = go.Scatter3d(
        x=coordinate_wise_xk_hist_np[:, 0],
        y=coordinate_wise_xk_hist_np[:, 1],
        z=HJ_MAD_CD_f_values,
        mode='lines+markers',
        marker=dict(size=5, color='blue'),
        line=dict(color='blue', width=3),
        name='HJ-MAD-CD'
    )

    # Global minimum point
    global_min_trace = go.Scatter3d(
        x=[x_true[0, 0].item()],
        y=[x_true[0, 1].item()],
        z=[global_min_f],
        mode='markers',
        marker=dict(size=8, color='black', symbol='x'),
        name='Global min'
    )

    # Initial guess point
    initial_guess_trace = go.Scatter3d(
        x=[x0[0, 0].item()],
        y=[x0[0, 1].item()],
        z=[f_initial],
        mode='markers',
        marker=dict(size=8, color='green', symbol='x'),
        name='Initial guess'
    )

    # Combine traces
    fig = go.Figure(data=[surface_trace, HJ_MAD_CD_trace, global_min_trace, initial_guess_trace])

    # Set layout details
    fig.update_layout(
        title="Interactive 3D Optimization Path",
        scene=dict(
            xaxis_title="X-axis",
            yaxis_title="Y-axis",
            zaxis_title="f-axis",
        ),
        margin=dict(l=0, r=0, t=40, b=0),
        legend=dict(
            x=0.02,  # Adjust the x position of the legend
            y=0.98,  # Adjust the y position of the legend
            bgcolor='rgba(255, 255, 255, 0.5)',  # Set background color with transparency
        )
    )

    # Show interactive plot
    fig.show(renderer="notebook")

# %%
if dim == 2:

    # Create the 3D plot
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    # Plot the surface
    ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='viridis', edgecolor='none', zorder=1)

    # # Plot the HJ-MAD optimization path
    # ax.plot(xk_hist_MAD_np[:, 0], xk_hist_MAD_np[:, 1], HJ_MAD_f_values, '-o', color='red', label="HJ-MAD", zorder=2)

    # Plot the HJ-MAD-CD optimization path
    ax.plot(coordinate_wise_xk_hist_np[:, 0], coordinate_wise_xk_hist_np[:, 1], HJ_MAD_CD_f_values, '-o', color='blue', label="HJ-MAD-CD", zorder=2)

    ax.plot(
        [x_true[0, 0].item()],  # Wrap in list
        [x_true[0, 1].item()],  # Wrap in list
        [global_min_f],  # Wrap in list
        'x', color='black', label="Global min", zorder=3
    )
    ax.plot(
        [x0[0, 0].item()],  # Wrap in list
        [x0[0, 1].item()],  # Wrap in list
        [f_initial],  # Wrap in list
        'x', color='green', label="Initial guess", zorder=3
    )

    # Set view angle
    ax.view_init(elev=50, azim=30)  # Increase the elevation angle to 90 degrees

    # Add labels and legend
    ax.set_xlabel('X-axis')
    ax.set_ylabel('Y-axis')
    ax.set_zlabel('f-axis')
    ax.legend()

    plt.show()
